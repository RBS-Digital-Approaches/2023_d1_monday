# %% [markdown]
# # Python hands-on with the five things a computer can do
# Carl provided a notebook with a high-level overview of the basic building blocks of pretty much any coding task. In this notebook, we'll put all of those into action to explore what seems like it should be a fairly simple question: in any given year, how many of the books printed by William Bowyer were by living authors, and how many were by dead ones?
#
# We won't take up those basic tasks in the same order as Carl's discussion, but rather as they crop up in the course of our task—I'll try to highlight where each of the things we do fits under those broad headings.
#
# If you haven't done much coding before, it may seem like there end up being an awful lot of steps involved, but what we're doing is breaking down that broad question into the smaller "computationally tractable" tasks it takes to answer it. If you spend more time doing this kind of work, a lot of what we'll do in this notebook will come to seem completely routine.
#
# If you *have* done a fair amount of coding before, you'll probably have immediately started thinking through how you'd go about exploring the question (or could start coming up with a plan in a minute or two). If that's you, you can probably skim past most of the discussion and cut straight to the code cells to make sure everything there makes sense.

# %% [markdown]
# ## Preliminary observations and caveats
# The aim of this notebook is to illustrate basic coding patterns using what could be a real book historical question. As such, the notebook ends up offering a simplified view both of coding and of book historical questions.
#
# The code here was written with an eye towards readability for people who may be relatively new to coding: there are probably more efficient and more elegant ways to handle lots of what we'll do here.
#
# There's also a *long* discussion to be had about something like ESTC records in this way. Suffice it to say that there are more steps we'd want to take if this were a real research question that we'll just dispense with in the interests of getting right into the code.

# %% [markdown]
# ## Let's just think about the problem for a second
# If we were looking at these records one at a time in a browser window, we wouldn't have any trouble saying whether the author of the book was alive or dead at the time of publication.
#
# But it's worth pausing to consider *how* we answer this question so easily: what are the steps we actually go through to decide, even if we move through them so quickly that they don't even feel like "steps"?
#
# It's worth pausing to think about that because, when you come down to it, we're going to have to make those steps explicit if we're going to make them happen in code.
#
# Here's some information from the first five records in the file we're going to be working with—the information we'd pay the most attention to if we were looking at these records in a tab in our browser with our question about living and dead authors in mind.
#
# >* Davila, Arrigo Caterino,(1576-1631). *The history of the civil wars of France*. (London:printed for D. Browne..., MDCCLVIII. \[1758\]).
# >
# >* Holland, Richard,(1688-1730). *Observations on the small pox: or, An essay to discover a more effectual method of cure*. (London:printed for John Brindley...,1728).
# >
# >* Hasledine, William,(1713 or 14-1773). *The beau and the academick*. (London: printed for J. Roberts,\[1733\]).
# >
# > * Clarke, John,(1687-1734).
# *A new grammar of the Latin tongue, comprising all necessary for grammar-schools*. (London: printed for L. Hawes, W. Clarke, and R. Collins..., M.DCC.LXVII. \[1767\]).
# >
# > * Spinckes, Nathaniel,(1654-1727). *The new pretenders to prophecy re-examined*. (London: printed for Richard Sare..., 1710).
#
# Take a minute or to think about the mental processes involved in deciding whether the author of the work was alive or dead in the year the book was published and jot a phrase/sentence or two about them in the cell below. Also take note of anything you see in these summaries that might cause you to have to spend a fraction of a second longer considering some of them.

# %%
#Jot down some notes on how you go about answering the simple question of
#whether the author of the record was living or dead in the year of publication.

# %% [markdown]
# ## Getting the tools we need
# In an example of what Carl termed "**distributed code reuse**," our first task is to get a Python package to help us read MARC records.
#
# While editing this notebook for brevity, I've had to cut out a lovingly-crafted section on the MARC format. There's a kind of "crash course" handout in the resources folder if you want to read a little bit more. If you want to read a lot more, you could curl up with the Library of Congress's documentation for the [MARC 21 format for bibliographic data](https://www.loc.gov/marc/bibliographic/).
#
# The long and short of it is that, while we probably could write code to read raw MARC records, ourselves, it makes a lot more sense to take advantage of the fact that somebody else has already written code to the job for us and is giving it away for free.
#
# `Pymarc` is a specialized-enough tool that it's not included by default in an installation of Python. We'll download it using `pip` (Package Installer for Python).

# %%
#Code cell #1
#Download and install the Pymarc package so that it's available for use in our
#Python environment
# !pip install pymarc
# Out:
# Collecting pymarc
#   Downloading pymarc-5.1.0-py3-none-any.whl (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.2/157.2 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: pymarc
# Successfully installed pymarc-5.1.0

# %% [markdown]
# We've now *installed* `Pymarc`, but to actually make use of it in our script, we need to `import` it. In this case, we just need the `MARCReader` module, so that's what we'll `import`.

# %%
#Code cell #2
#Import the MARCReader module from the Pymarc package.
from pymarc import MARCReader

# %% [markdown]
# ## Opening a MARC file
# With `Pymarc` installed and the `MARCReader` module available to our script, we're ready to start dealing with MARC records! Awesome. Now we need some MARC records. And those are in a file. So we have to open a file, which obviously brings us to another of Carl's five things (**input and output**), but also—perhaps somewhat less obviously—brings us to another of the five things: **variables**.

# %% [markdown]
# We want to open a file that you have in the `rbs_digital_approaches_2023/2023_data_class` folder that you've cloned from GitHub  to Google Drive. To do that, we first have to import the code that allows Google Colaboratory to talk with Google Drive, as we did in the first session.

# %%
#Code cell #3
from google.colab import drive
drive.mount('/gdrive/')
# Out:
# Mounted at /gdrive/

# %% [markdown]
# To actually work with any of our files, we'll need to provide a full file path to each file we want. Since all of those files are going to be in the same place, let's just create a variable to hold the path to the directory we want.
#
# Then, any time we need to get a file in this directory, we can just use the variable name instead of re-typing the full path.

# %%
#Code cell #4
directory_path = '/gdrive/MyDrive/rbs_digital_approaches_2023/2023_data_class/'

# %% [markdown]
# This next cell presents the most common way of opening a file in Python. There are a couple of different things going on here, which can make this convention a little confusing at first.
#
# Before getting into the content of the lines, first note the structure: the first line begins with `with` and ends with a colon, which is setting a **condition** for the code that follows (this is one example of the kind of **control structures** that Carl's notebook mentions).
#
# Notice, especially, that the second line is indented. This is important because, in Python, *whitespace has meaning*. Python infers just from the whitespace that the code in line two happens "inside" the code on line one. If line two weren't indented properly, we'd end up with an error.
#
# Now for the content of the lines. We're using the `open` command and giving it two "arguments" inside the parentheses:
# 1. The path to the file we want to open (which I've built up here by using the `directory_path` and adding the name of the specific file I want).
# 2. The way we want to open the file. In this case, `rb` stands for "readable" and "binary" (as opposed to text: `MARCReader` wants to read the MARC records as bytes). We'll see other variations this week.
#
# Then—still in line 1—we're creating a new variable (`marc_file`) to represent the file we've just opened. This part can be a little confusing because it's not necessarily obvious that the word `as` would mean something like "Create a new variable and assign a value to it," but that's what's implicit in that formula. (Opening files is something you have to do a lot, so having a very terse, economical syntax for doing it is a real convenience.)
#
# Line two creates *another* variable (`marc_reader`). We're giving our MARC file to the `MARCReader` module to handle (saying, in effect, "Uh, you know how to read this stuff, right?"). `MARCReader` will then allow us to deal with the contents of the MARC records in our file in ways that are more congenial for Python coding. From now on, we'll use `marc_reader` to refer to the representation of our file that the MARC-savvy `MARCReader` module constructs for us.
#
# For now, we'll just have `MARCReader` print the records out for us.

# %%
#Code cell #5
#Open a file in readable binary mode and refer to it as marc_file
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  #Give marc_file to MARCReader and refer to whatever we get back as marc_reader
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    print(record)
# Out:
# =LDR  01493nam a2200229   4500
# =001  N10049
# =003  CU-RivES\
# =005  20090206223027.0
# =008  840710s1758\\\\enk||||\\\\\\\00|\||eng\c
# =009  006000111\
# =035  \\$a(Uk-ES)006000111
# =040  \\$aCU-RivES$cCU-RivES$dCU-RivES$dCStRLIN$dCU-RivES
# =100  1\$aDavila, Arrigo Caterino,$d1576-1631.
# =240  10$aIstoria delle guerre civilé di Francia.$lEnglish
# =245  14$aThe history of the civil wars of France.$bIn which are related, the most remarkable transactions that happened during the reigns of Francis the Second, Charles the Ninth, Henry the Third, and, Henry the Fourth, surnamed the Great. A new translation from the Italian of Henrico Caterino Davila. By Ellis Farneworth, M. A. ...
# =260  \\$aLondon :$bprinted for D. Browne, without Temple-Bar A. Millar, in the Strand J. Whiston and B. White, in Fleet-Street R. and J. Dodsley, in Pall-Mall and W. Sandby, in Fleet-Street,$cMDCCLVIII. [1758]
# =300  \\$a2v. ;$c4⁰.
# =533  \\$aMicrofilm.$bWoodbridge, Conn.:$cPrimary Source Media,$d1999.$e1 reel ; 35 mm.$f(The Eighteenth Century ; reel 10545, no. 02).$7s1999 ctu b
# =533  \\$aElectronic reproduction.$bFarmington Hills, Mich. :$cThomson Gale,$d2003.$f(Eighteenth century collections online).$nAvailable via the World Wide Web.$nAccess limited by licensing agreements.
# =648  \7$a1701-1800$2local
# =651  \0$aFrance$xHistory$yWars of the Huguenots, 1562-1598.
# =752  \\$aGreat Britain$bEngland$dLondon.
#
# =LDR  01693cam a2200289   4500
# =001  N10081
# =003  CU-RivES
# =005  20091118161529.0
# =008  840710s1728\\\\enk||||\\\\\\\00|\||eng\c
# =009  006000146
# =035  \\$a(Uk-ES)006000146
# =040  \\$aCU-RivES$cCU-RivES$dCU-RivES$dCStRLIN$dCU-RivES
# =100  1\$aHolland, Richard,$d1688-1730.
# =245  10$aObservations on the small pox: or, An essay to discover a more effectual method of cure.$bBy Richard Holland, M.D. Fellow of the College of Physicians and the Royal Society.
# =260  \\$aLondon :$bprinted for John Brindley, Bookbinder to the Majesty, at the King's Arms in New-Bond-Street,$c1728.
# =300  \\$a[8],xix,[1],76,79-164[i.e.162]p. ;$c8⁰.
# =500  \\$aP.162 misnumbered 164; variant: p.162 correctly numbered.
# =500  \\$aText is continuous despite pagination.
# =500  \\$aSig.O3 (pp.83-84) and sig.Q4 (pp.101-102) are cancels; p.83 line 5 ends: "too"; p.101 line 14 ends: "the".
# =500  \\$aIn some copies, sigs. O3 and Q4 have not been cancelled; p.83 line 5 ends: "as"; p.101 line 14 ends: "strenghen".
# =500  \\$aPrinted by William Bowyer; his records show 350 ordinary and 150 large-paper copies printed.
# =510  4\$aMaslen & Lancaster. Bowyer ledgers,$c1365
# =533  \\$aMicrofilm.$bWoodbridge, CT$cResearch Publications, Inc.,$d1988.$e1 reel ; 35mm.$f(The Eighteenth Century ; reel 3073, no. 8).
# =533  \\$aElectronic reproduction.$bFarmington Hills, Mich. :$cThomson Gale,$d2003.$f(Eighteenth century collections online).$nAvailable via the World Wide Web.$nAccess limited by licensing agreements.
# =648  \7$a1701-1800$2local
# =650  \0$aSmallpox.
# =752  \\$aGreat Britain$bEngland$dLondon.
#
# =LDR  01208cam a2200289   4500
# =001  N101
# =003  CU-RivES\
# =005  20090516220242.0
# =008  820917s1733\\\\enk||||\\\\\\\00|\||eng\c
# =009  006000166\
# =035  \\$a(Uk-ES)006000166
# =040  \\$aCU-RivES$cCU-RivES$dUk-ES$dCStRLIN
# =100  1\$aHasledine, William,$d1713 or 14-1773.
# =240  10$aBellus homo et academicus.$lEnglish
# =245  14$aThe beau and the academick.$bA dialogue in imitation of Bellus homo and academicus, spoken at the late publick act at Oxford. Address'd to the ladies.
# =260  \\$aLondon :$bprinted for J. Roberts,$c[1733]
# =300  \\$a[4],12p. ;$c4⁰.
# =500  \\$aPreface signed: Bellamant i.e. William Bowyer.
# =500  \\$aA translation of William Hasledine's 'Bellus homo et academicus', 1733.
# =500  \\$aPrinted by William Bowyer; his records show 500 copies printed for himself and Innys as partners.
# =500  \\$aSignatures: A² B⁴ C².
# =500  \\$aSignatures from Maslen & Lancaster, and Foxon.
# =510  4\$aFoxon,$cB337
# =510  4\$aMaslen & Lancaster. Bowyer ledgers,$c1975
# =648  \7$a1701-1800$2local
# =700  1\$aBowyer, William,$d1699-1777.
# =752  \\$aGreat Britain$bEngland$dLondon.
#
# =LDR  01544nam a2200277   4500
# =001  N10263
# =003  CU-RivES
# =005  20060812125846.0
# =008  840716s1767\\\\enk||||\\\\\\\00||||eng\c
# =009  006000348
# =035  \\$a(Uk-ES)006000348
# =040  \\$aCU-RivES$cCU-RivES$dCStRLIN$dCU-RivES
# =100  1\$aClarke, John,$d1687-1734.
# =245  12$aA new grammar of the Latin tongue, comprising all necessary for grammar-schools.$bTo which is annexed a dissertation upon language. By John Clarke, Author of the Two Essays upon Education and Study, Introduction to the Making of Latin, &c.
# =246  3\$aNew grammar of the Latin tongue, comprising all in the art necessary for grammar-schools
# =250  \\$aThe fifth edition, corrected.
# =260  \\$aLondon :$bprinted for L. Hawes, W. Clarke, and R. Collins, in Pater-Noster Row,$cM.DCC.LXVII. [1767]
# =300  \\$axv,[3],173,[1]p. ;$c12⁰.
# =509  \\$aThe leaf following that numbered xv on recto is numbered 18, 17
# =533  \\$aMicrofilm.$bWoodbridge, CT$cResearch Publications, Inc.,$d1986.$e1 reel ; 35mm.$f(The Eighteenth Century ; reel 1583, no. 04).
# =533  \\$aElectronic reproduction.$bFarmington Hills, Mich. :$cThomson Gale,$d2003.$f(Eighteenth century collections online).$nAvailable via the World Wide Web.$nAccess limited by licensing agreements.
# =648  \7$a1701-1800$2local
# =650  \0$aLatin language$xGrammar$vEarly works to 1800.
# =655  \7$aGrammars.$2rbgenr
# =752  \\$aGreat Britain$bEngland$dLondon.
# =985  \\$aSubject headings created by HTC$dMay 2008$inCU-RivES
#
# =LDR  01565cam a2200301   4500
# =001  N10280
# =003  CU-RivES\
# =005  20080503043207.0
# =008  840716s1710\\\\enk||||\\\\\\\00|\||eng\c
# =009  006000366\
# =035  \\$a(Uk-ES)006000366
# =040  \\$aCU-RivES$cCU-RivES$dCStRLIN$dCU-RivES
# =100  1\$aSpinckes, Nathaniel,$d1654-1727.
# =245  14$aThe new pretenders to prophecy re-examined:$band their pretences shewn to be groundless and false. And Sir R. Bulkeley and A. Whitro convicted of very foul practices, in order to the carrying on their imposture. By N. Spinckes a Presbyter of the Church of England.
# =260  \\$aLondon :$bprinted for Richard Sare, at Grays-Inn-Gate in Holbourn,$c1710.
# =300  \\$axvi,56p. ;$c8⁰.
# =500  \\$aOn A. Whitrow's 'The warnings of the eternal spirit' with preface by Sir Richard Bulkeley.
# =500  \\$aAnother issue omits "And Sir R. Bulkeley and A. Whitro convicted of very foul practices, in order to the carrying on their imposture." in title.
# =500  \\$aPrinted by William Bowyer.
# =500  \\$aSignatures: A-D⁸ E⁴.
# =500  \\$aSignatures from Maslen & Lancaster.
# =510  4\$aMaslen & Lancaster. Bowyer ledgers,$c24
# =533  \\$aMicrofilm.$bWoodbridge, CT$cResearch Publications, Inc.,$d1985.$e1 reel ; 35mm.$f(The Eighteenth Century ; reel 1273, no. 29).
# =600  10$aBulkeley, Richard,$cSir,$d1644-1710.
# =600  10$aWhitrow, Abraham.$tWarnings of the eternal spirit.
# =648  \7$a1701-1800$2local
# =650  \0$aProphets$zGreat Britain.
# =752  \\$aGreat Britain$bEngland$dLondon.
#
# =LDR  01298cam a2200229   4500
# =001  N10407
# =003  CU-RivES
# =005  20100930153905.0
# =008  840719s1743\\\\enk||||\\\\\\\00||||eng\c
# =009  006000507
# =035  \\$a(Uk-ES)006000507
# =040  \\$aCU-RivES$cCU-RivES$dCStRLIN$dCU-RivES
# =245  00$aLaws relating to the poor,$bfrom the forty-third of Queen Elizabeth to the third of King George II. With cases adjudged in the Court of King's Bench, upon the several Clauses of them. In a Method entirely New. The second edition corrected. By Robert Foley Esq; Barrister at Law.
# =260  \\$a[London] :$bIn the Savoy: printed by Henry Lintot (assignee of Edw. Sayer, Esq;) for T. Woodward, at the Half-Moon between the Temple Gates in Fleet-Street,$cMDCCXLIII. [1743]
# =300  \\$a[32],284,[20]p. ;$c8⁰.
# =500  \\$aCompiled and edited by Robert Foley.
# =509  \\$aBacklog2009
# =533  \\$aMicrofilm.$bWoodbridge, CT$cResearch Publications, Inc.,$d1986$e1 reel ; 35mm.$f(The Eighteenth Century ; reel 1718, no.06).
# =533  \\$aMicrofilm.$bNew Haven, CT$cResearch Publications, Inc.,$d1974.$e1 reel ; 35mm.$f(Goldsmiths-Kress Library of Economic Literature ; reel 530, no. 8006).
# =648  \7$a1701-1800$2local
# =650  \0$aPoor laws$zGreat Britain.
# =752  \\$aGreat Britain$bEngland$dLondon.

# %% [markdown]
# ## Iterating through the records with MARCReader
# The code in lines 5 and 6, above, is another **control structure** known as a `for` loop.
#
# Notice how line 5 (beginning with `for`) is indented to be "inside" the `with` statement, and that line 6 is indented to be "inside" the `for` loop—we have a nested control structure here, and it's all signaled by white space.
#
# Our `for` loop creates, in passing, yet another **variable** (`record`). It says, essentially:
# * `marc_reader` contains an unknown number of things. We'll call each of those things `record`, in turn.
#     * Print the contents of every `record`.
#
# (In this cell, we're starting with a very small subset of the records we'll work with eventually—the full file is large enough that Colaboratory would complain about the I/O rate and cut our notebook off temporarily if we tried to simpy print all of the records like this).

# %% [markdown]
# ### Getting individual fields from each MARC record
# Now we know that there are, in fact MARC records, but just printing out the full record doesn't do us much good. Let's get just a single field from each record.

# %%
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    print(record['245'])
# Out:
# =245  14$aThe history of the civil wars of France.$bIn which are related, the most remarkable transactions that happened during the reigns of Francis the Second, Charles the Ninth, Henry the Third, and, Henry the Fourth, surnamed the Great. A new translation from the Italian of Henrico Caterino Davila. By Ellis Farneworth, M. A. ...
# =245  10$aObservations on the small pox: or, An essay to discover a more effectual method of cure.$bBy Richard Holland, M.D. Fellow of the College of Physicians and the Royal Society.
# =245  14$aThe beau and the academick.$bA dialogue in imitation of Bellus homo and academicus, spoken at the late publick act at Oxford. Address'd to the ladies.
# =245  12$aA new grammar of the Latin tongue, comprising all necessary for grammar-schools.$bTo which is annexed a dissertation upon language. By John Clarke, Author of the Two Essays upon Education and Study, Introduction to the Making of Latin, &c.
# =245  14$aThe new pretenders to prophecy re-examined:$band their pretences shewn to be groundless and false. And Sir R. Bulkeley and A. Whitro convicted of very foul practices, in order to the carrying on their imposture. By N. Spinckes a Presbyter of the Church of England.
# =245  00$aLaws relating to the poor,$bfrom the forty-third of Queen Elizabeth to the third of King George II. With cases adjudged in the Court of King's Bench, upon the several Clauses of them. In a Method entirely New. The second edition corrected. By Robert Foley Esq; Barrister at Law.

# %% [markdown]
# Okay, but we're still getting stuff we don't want, like the field codes, the MARC indicators, and subfield codes. Let's just get the text content of the subfield a of field 245, which holds the main title.
#
# (Notice how, with `MARCReader`, we're getting specific sections of a field by adding information in square brackets—this is a common pattern we'll see again. In this case we're putting the names of the fields we want in quotation marks; in other cases we might use numbers, instead.)

# %%
#Code cell #6
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    print(record['245']['a'])
# Out:
# The history of the civil wars of France.
# Observations on the small pox: or, An essay to discover a more effectual method of cure.
# The beau and the academick.
# A new grammar of the Latin tongue, comprising all necessary for grammar-schools.
# The new pretenders to prophecy re-examined:
# Laws relating to the poor,

# %% [markdown]
# While we're at it, let's construct a variable of our own that will hold both the main title at the continuation of the title as a text string. This is "basic math" of a kind, in that we're creating `full_title` by adding together the contents of `['245']['a']` and `['245']['b']`.

# %%
#Code cell #7
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    full_title = record['245']['a'] + record['245']['b']
    print(full_title)
# Out:
# The history of the civil wars of France.In which are related, the most remarkable transactions that happened during the reigns of Francis the Second, Charles the Ninth, Henry the Third, and, Henry the Fourth, surnamed the Great. A new translation from the Italian of Henrico Caterino Davila. By Ellis Farneworth, M. A. ...
# Observations on the small pox: or, An essay to discover a more effectual method of cure.By Richard Holland, M.D. Fellow of the College of Physicians and the Royal Society.
# The beau and the academick.A dialogue in imitation of Bellus homo and academicus, spoken at the late publick act at Oxford. Address'd to the ladies.
# A new grammar of the Latin tongue, comprising all necessary for grammar-schools.To which is annexed a dissertation upon language. By John Clarke, Author of the Two Essays upon Education and Study, Introduction to the Making of Latin, &c.
# The new pretenders to prophecy re-examined:and their pretences shewn to be groundless and false. And Sir R. Bulkeley and A. Whitro convicted of very foul practices, in order to the carrying on their imposture. By N. Spinckes a Presbyter of the Church of England.
# Laws relating to the poor,from the forty-third of Queen Elizabeth to the third of King George II. With cases adjudged in the Court of King's Bench, upon the several Clauses of them. In a Method entirely New. The second edition corrected. By Robert Foley Esq; Barrister at Law.

# %% [markdown]
# If you look closely, you'll notice a little problem with the `full_title` variable we created in the last cell:
# >
# ```
# The history of the civil wars of France.In which are related, ...
# ...more effectual method of cure.By Richard Holland...
# The beau and the academick.A dialogue in...
# ...necessary for grammar schools.To which is annexed...
# ```
# >
# Our script did exactly what we said: it took the string of text in `['245']['a']` and added the string of text in `['245']['b']` to it. We never said anything about putting a space between those two strings of text
#
# Based on what we've seen about "adding" strings of text together in the last cell, try to construct the `full_title` variable to address the problem of the missing space.

# %%
#Write-your-own-code cell A
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    #Construct the value of the full_title variable in a way that includes a
    #space between the content of the two subfields
    full_title =
    print(full_title)

# %% [markdown]
# ### Conditionals
# Printing out the title for every record is a safe bet because every record *has* to have something in the 245 field—you can't have a book without a title.
#
# But look what happens when we try to print out the contents of field 100, subfield a: the author's name

# %%
#Code cell 8
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    print(record['100']['a'] + ' ' + record['100']['d'])
# Out:
# Davila, Arrigo Caterino, 1576-1631.
# Holland, Richard, 1688-1730.
# Hasledine, William, 1713 or 14-1773.
# Clarke, John, 1687-1734.
# Spinckes, Nathaniel, 1654-1727.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-9fd57e0be4e7> in <cell line: 2>()
#       3   marc_reader = MARCReader(marc_file)
#       4   for record in marc_reader :
# ----> 5     print(record['100']['a'] + ' ' + record['100']['d'])
#
# /usr/local/lib/python3.10/dist-packages/pymarc/record.py in __getitem__(self, tag)
#     147         """
#     148         if tag not in self:
# --> 149             raise KeyError
#     150
#     151         fields: List[Field] = self.get_fields(tag)
#
# KeyError:

# %% [markdown]
# Whoops. Something's not working with the last record. Let's have a look.

# %%
#Code cell #9
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    print(record)
# Out:
# =LDR  01493nam a2200229   4500
# =001  N10049
# =003  CU-RivES\
# =005  20090206223027.0
# =008  840710s1758\\\\enk||||\\\\\\\00|\||eng\c
# =009  006000111\
# =035  \\$a(Uk-ES)006000111
# =040  \\$aCU-RivES$cCU-RivES$dCU-RivES$dCStRLIN$dCU-RivES
# =100  1\$aDavila, Arrigo Caterino,$d1576-1631.
# =240  10$aIstoria delle guerre civilé di Francia.$lEnglish
# =245  14$aThe history of the civil wars of France.$bIn which are related, the most remarkable transactions that happened during the reigns of Francis the Second, Charles the Ninth, Henry the Third, and, Henry the Fourth, surnamed the Great. A new translation from the Italian of Henrico Caterino Davila. By Ellis Farneworth, M. A. ...
# =260  \\$aLondon :$bprinted for D. Browne, without Temple-Bar A. Millar, in the Strand J. Whiston and B. White, in Fleet-Street R. and J. Dodsley, in Pall-Mall and W. Sandby, in Fleet-Street,$cMDCCLVIII. [1758]
# =300  \\$a2v. ;$c4⁰.
# =533  \\$aMicrofilm.$bWoodbridge, Conn.:$cPrimary Source Media,$d1999.$e1 reel ; 35 mm.$f(The Eighteenth Century ; reel 10545, no. 02).$7s1999 ctu b
# =533  \\$aElectronic reproduction.$bFarmington Hills, Mich. :$cThomson Gale,$d2003.$f(Eighteenth century collections online).$nAvailable via the World Wide Web.$nAccess limited by licensing agreements.
# =648  \7$a1701-1800$2local
# =651  \0$aFrance$xHistory$yWars of the Huguenots, 1562-1598.
# =752  \\$aGreat Britain$bEngland$dLondon.
#
# =LDR  01693cam a2200289   4500
# =001  N10081
# =003  CU-RivES
# =005  20091118161529.0
# =008  840710s1728\\\\enk||||\\\\\\\00|\||eng\c
# =009  006000146
# =035  \\$a(Uk-ES)006000146
# =040  \\$aCU-RivES$cCU-RivES$dCU-RivES$dCStRLIN$dCU-RivES
# =100  1\$aHolland, Richard,$d1688-1730.
# =245  10$aObservations on the small pox: or, An essay to discover a more effectual method of cure.$bBy Richard Holland, M.D. Fellow of the College of Physicians and the Royal Society.
# =260  \\$aLondon :$bprinted for John Brindley, Bookbinder to the Majesty, at the King's Arms in New-Bond-Street,$c1728.
# =300  \\$a[8],xix,[1],76,79-164[i.e.162]p. ;$c8⁰.
# =500  \\$aP.162 misnumbered 164; variant: p.162 correctly numbered.
# =500  \\$aText is continuous despite pagination.
# =500  \\$aSig.O3 (pp.83-84) and sig.Q4 (pp.101-102) are cancels; p.83 line 5 ends: "too"; p.101 line 14 ends: "the".
# =500  \\$aIn some copies, sigs. O3 and Q4 have not been cancelled; p.83 line 5 ends: "as"; p.101 line 14 ends: "strenghen".
# =500  \\$aPrinted by William Bowyer; his records show 350 ordinary and 150 large-paper copies printed.
# =510  4\$aMaslen & Lancaster. Bowyer ledgers,$c1365
# =533  \\$aMicrofilm.$bWoodbridge, CT$cResearch Publications, Inc.,$d1988.$e1 reel ; 35mm.$f(The Eighteenth Century ; reel 3073, no. 8).
# =533  \\$aElectronic reproduction.$bFarmington Hills, Mich. :$cThomson Gale,$d2003.$f(Eighteenth century collections online).$nAvailable via the World Wide Web.$nAccess limited by licensing agreements.
# =648  \7$a1701-1800$2local
# =650  \0$aSmallpox.
# =752  \\$aGreat Britain$bEngland$dLondon.
#
# =LDR  01208cam a2200289   4500
# =001  N101
# =003  CU-RivES\
# =005  20090516220242.0
# =008  820917s1733\\\\enk||||\\\\\\\00|\||eng\c
# =009  006000166\
# =035  \\$a(Uk-ES)006000166
# =040  \\$aCU-RivES$cCU-RivES$dUk-ES$dCStRLIN
# =100  1\$aHasledine, William,$d1713 or 14-1773.
# =240  10$aBellus homo et academicus.$lEnglish
# =245  14$aThe beau and the academick.$bA dialogue in imitation of Bellus homo and academicus, spoken at the late publick act at Oxford. Address'd to the ladies.
# =260  \\$aLondon :$bprinted for J. Roberts,$c[1733]
# =300  \\$a[4],12p. ;$c4⁰.
# =500  \\$aPreface signed: Bellamant i.e. William Bowyer.
# =500  \\$aA translation of William Hasledine's 'Bellus homo et academicus', 1733.
# =500  \\$aPrinted by William Bowyer; his records show 500 copies printed for himself and Innys as partners.
# =500  \\$aSignatures: A² B⁴ C².
# =500  \\$aSignatures from Maslen & Lancaster, and Foxon.
# =510  4\$aFoxon,$cB337
# =510  4\$aMaslen & Lancaster. Bowyer ledgers,$c1975
# =648  \7$a1701-1800$2local
# =700  1\$aBowyer, William,$d1699-1777.
# =752  \\$aGreat Britain$bEngland$dLondon.
#
# =LDR  01544nam a2200277   4500
# =001  N10263
# =003  CU-RivES
# =005  20060812125846.0
# =008  840716s1767\\\\enk||||\\\\\\\00||||eng\c
# =009  006000348
# =035  \\$a(Uk-ES)006000348
# =040  \\$aCU-RivES$cCU-RivES$dCStRLIN$dCU-RivES
# =100  1\$aClarke, John,$d1687-1734.
# =245  12$aA new grammar of the Latin tongue, comprising all necessary for grammar-schools.$bTo which is annexed a dissertation upon language. By John Clarke, Author of the Two Essays upon Education and Study, Introduction to the Making of Latin, &c.
# =246  3\$aNew grammar of the Latin tongue, comprising all in the art necessary for grammar-schools
# =250  \\$aThe fifth edition, corrected.
# =260  \\$aLondon :$bprinted for L. Hawes, W. Clarke, and R. Collins, in Pater-Noster Row,$cM.DCC.LXVII. [1767]
# =300  \\$axv,[3],173,[1]p. ;$c12⁰.
# =509  \\$aThe leaf following that numbered xv on recto is numbered 18, 17
# =533  \\$aMicrofilm.$bWoodbridge, CT$cResearch Publications, Inc.,$d1986.$e1 reel ; 35mm.$f(The Eighteenth Century ; reel 1583, no. 04).
# =533  \\$aElectronic reproduction.$bFarmington Hills, Mich. :$cThomson Gale,$d2003.$f(Eighteenth century collections online).$nAvailable via the World Wide Web.$nAccess limited by licensing agreements.
# =648  \7$a1701-1800$2local
# =650  \0$aLatin language$xGrammar$vEarly works to 1800.
# =655  \7$aGrammars.$2rbgenr
# =752  \\$aGreat Britain$bEngland$dLondon.
# =985  \\$aSubject headings created by HTC$dMay 2008$inCU-RivES
#
# =LDR  01565cam a2200301   4500
# =001  N10280
# =003  CU-RivES\
# =005  20080503043207.0
# =008  840716s1710\\\\enk||||\\\\\\\00|\||eng\c
# =009  006000366\
# =035  \\$a(Uk-ES)006000366
# =040  \\$aCU-RivES$cCU-RivES$dCStRLIN$dCU-RivES
# =100  1\$aSpinckes, Nathaniel,$d1654-1727.
# =245  14$aThe new pretenders to prophecy re-examined:$band their pretences shewn to be groundless and false. And Sir R. Bulkeley and A. Whitro convicted of very foul practices, in order to the carrying on their imposture. By N. Spinckes a Presbyter of the Church of England.
# =260  \\$aLondon :$bprinted for Richard Sare, at Grays-Inn-Gate in Holbourn,$c1710.
# =300  \\$axvi,56p. ;$c8⁰.
# =500  \\$aOn A. Whitrow's 'The warnings of the eternal spirit' with preface by Sir Richard Bulkeley.
# =500  \\$aAnother issue omits "And Sir R. Bulkeley and A. Whitro convicted of very foul practices, in order to the carrying on their imposture." in title.
# =500  \\$aPrinted by William Bowyer.
# =500  \\$aSignatures: A-D⁸ E⁴.
# =500  \\$aSignatures from Maslen & Lancaster.
# =510  4\$aMaslen & Lancaster. Bowyer ledgers,$c24
# =533  \\$aMicrofilm.$bWoodbridge, CT$cResearch Publications, Inc.,$d1985.$e1 reel ; 35mm.$f(The Eighteenth Century ; reel 1273, no. 29).
# =600  10$aBulkeley, Richard,$cSir,$d1644-1710.
# =600  10$aWhitrow, Abraham.$tWarnings of the eternal spirit.
# =648  \7$a1701-1800$2local
# =650  \0$aProphets$zGreat Britain.
# =752  \\$aGreat Britain$bEngland$dLondon.
#
# =LDR  01298cam a2200229   4500
# =001  N10407
# =003  CU-RivES
# =005  20100930153905.0
# =008  840719s1743\\\\enk||||\\\\\\\00||||eng\c
# =009  006000507
# =035  \\$a(Uk-ES)006000507
# =040  \\$aCU-RivES$cCU-RivES$dCStRLIN$dCU-RivES
# =245  00$aLaws relating to the poor,$bfrom the forty-third of Queen Elizabeth to the third of King George II. With cases adjudged in the Court of King's Bench, upon the several Clauses of them. In a Method entirely New. The second edition corrected. By Robert Foley Esq; Barrister at Law.
# =260  \\$a[London] :$bIn the Savoy: printed by Henry Lintot (assignee of Edw. Sayer, Esq;) for T. Woodward, at the Half-Moon between the Temple Gates in Fleet-Street,$cMDCCXLIII. [1743]
# =300  \\$a[32],284,[20]p. ;$c8⁰.
# =500  \\$aCompiled and edited by Robert Foley.
# =509  \\$aBacklog2009
# =533  \\$aMicrofilm.$bWoodbridge, CT$cResearch Publications, Inc.,$d1986$e1 reel ; 35mm.$f(The Eighteenth Century ; reel 1718, no.06).
# =533  \\$aMicrofilm.$bNew Haven, CT$cResearch Publications, Inc.,$d1974.$e1 reel ; 35mm.$f(Goldsmiths-Kress Library of Economic Literature ; reel 530, no. 8006).
# =648  \7$a1701-1800$2local
# =650  \0$aPoor laws$zGreat Britain.
# =752  \\$aGreat Britain$bEngland$dLondon.

# %% [markdown]
# It turns out not every record has a `100` field.
#
# Let's put in a **conditional** statement to first see if there *is* a `100` field before trying to print the author's name.
# >Note: In earlier versions of this notebook I used a different syntax that is fairly standard in Python, but that stopped working with a recent update to PyMarc. This code uses PyMarc's `get` function to test whether a field exists: we pass the field code and a default value (in this case `None`). If the field exists, we'll get its value; but if it doesn't exist, we'll get back the default value we supplied. If we get back anything other than `None`, we know there's a 100 field and we can execute the conditional code. If there's not a 100 field, then we won't pass this conditional check and will move to the code that comes after `else`.

# %%
#Code cell #10
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    if record.get('100', None) is not None :
      print(record['100']['a'] + ' ' + record['100']['d'])
    else :
      print('No 100 field')
# Out:
# Davila, Arrigo Caterino, 1576-1631.
# Holland, Richard, 1688-1730.
# Hasledine, William, 1713 or 14-1773.
# Clarke, John, 1687-1734.
# Spinckes, Nathaniel, 1654-1727.
# No 100 field

# %% [markdown]
# ### Try this for yourself
# In the cell below, write code that will:
# 1. Open the MARC file we've been working with;
# 2. Pass that file to MARCReader
# 3. Iterate through the records and print:
#     * The contents of field 100, subfield a and field 100, subfield d, **if that field exists**
#     * The contents of field 260, subfield c, **if that field exists**

# %%
#Write-your-own-code cell B
#Your code goes here:

# %% [markdown]
# ### One solution
# If you're running into trouble, click to reveal a solution.

# %%
#Suggestion code cell 1
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    if record.get('100', None) is not None :
      print(record['100']['a'] + ' ' + record['100']['d'])
    if record.get('260', None) is not None :
      print(record['260']['c'])
# Out:
# Davila, Arrigo Caterino, 1576-1631.
# MDCCLVIII. [1758]
# Holland, Richard, 1688-1730.
# 1728.
# Hasledine, William, 1713 or 14-1773.
# [1733]
# Clarke, John, 1687-1734.
# M.DCC.LXVII. [1767]
# Spinckes, Nathaniel, 1654-1727.
# 1710.
# MDCCXLIII. [1743]

# %% [markdown]
# ## Getting the information we need
# To figure out whether an author was alive or dead the year a work was published, we need to know the year the work was published. As we saw above, field 260|c gives the date *as it appears on the title page*.
#
# As it happens, though, another part of the MARC record also has the publication date, and it's presented in such a way that we won't have to deal with things like Roman numerals. The MARC 008 field is a structured data field that tells us about things like country of publication, language, and date of publication. Let's have a look at that field. (Note that MARC "control fields," including 008 field, don't have subfields, so we need to use `.data` to get the content of those fields.)

# %%
#Code cell #11
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    print(record['008'].data)
# Out:
# 840710s1758    enk||||       00| ||eng c
# 840710s1728    enk||||       00| ||eng c
# 820917s1733    enk||||       00| ||eng c
# 840716s1767    enk||||       00||||eng c
# 840716s1710    enk||||       00| ||eng c
# 840719s1743    enk||||       00||||eng c

# %% [markdown]
# Looking at [the documentation for the 008 field](https://www.loc.gov/marc/bibliographic/bd008a.html), we can see what parts of this fixed-length field are actually helpful to us.
# * Character 6 tells us what *kind* of date (or dates) the field provides: a single year, multiple years, etc. (There are only single years in this subset, but there are other combinations to be found in the full set.)
# * If there's only one year, we'll find it in characters 7-10; if there are two years, characters 7-10 will give us the first year and characters 11-14 will give us the second year.
#
# This is one of those cases where we'd really need to know our data better to know what would give us the *best* answer, but for demonstration purposes, let's just treat the first year (that is, the one in characters 7-10) as our publication year. (**Note:** This is just one factor in this quick demonstration that means what we're getting from this notebook should not be considered a real answer to our book historical question!)

# %% [markdown]
# ### Slicing a substring from a longer string
# We can get just the characters that interest us by indicating a starting and ending point in the string (a position like this is referred to as an "index"). The MARC documentation tells us exactly which characters, so let's try getting our string from character 7 to character 10.
#
# Just like we used information in square brackets to get segments of MARC fields, we can add information in square brackets to get just a portion of MARC field 008. We can "slice" a string by indicating where we want to start and where we want to stop. So, if we're looking for characters 7-10, we might expect to use something like `record['008].data[7:10]`.
#
# There are two things we need to bear in mind here:
# * In Python, we start counting at zero, rather than one. (The MARC documentation also starts counting at zero, so we're okay there.)
# * In Python, when we're slicing something like a string of text, the starting point of a slice is inclusive, but the ending point is exclusive: we get everything up to *but not including* the ending.
#
# This can be confusing at first, but it's actually kind of nice because it means you can know how many elements you're going to get back by subtracting the first number from the second: `[7:10]` would only get us three digits. We want `[7:11]`, instead, which will get us the four characters starting at character 7 and going up to (but not including) character 11.

# %%
#Code cell #12
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    print(record['008'].data[7:11])
# Out:
# 1758
# 1728
# 1733
# 1767
# 1710
# 1743

# %% [markdown]
# ### More ways of manipulating strings of text
# We're in pretty good shape for the publication years. Now let's turn to the authors' dates.
#
# Unlike the 008 field, which has a predictable, fixed length, authors dates can come in lots of different forms, and we need to figure out how to get just the part of that field that interests us.
#
# Python has a lot of different [methods for working with strings of text](https://docs.python.org/3/library/stdtypes.html?highlight=split#string-methods)—more than we can reasonably cover in an hour or so. We'll try to explain various methods that we use as they come up in the code we'll use this week, but feel free to ask about anything that seems unclear.
#
# We'll stick with the subset of records we've been working with for the time being to figure out an approach that will work for most of our cases, but then we'll look at a different subset selected to bring certain problems into view.
#
# Let's begin by just looking at the authors' dates again.

# %%
#Code cell #13
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    if record.get('100', None) is not None :
      print(record['100']['d'])
# Out:
# 1576-1631.
# 1688-1730.
# 1713 or 14-1773.
# 1687-1734.
# 1654-1727.

# %% [markdown]
# #### Finding a substring
# We know we want the digits after the hyphen, it's just that we can't know ahead of time where the hyphen will be in every string of text we find in a 100|d subfield.
#
# But if we can find the hyphen, we'd at least have a way of knowing our starting index. We can use Python's built-in `find()` method to locate the hyphen. The way this is written can be confusing at first: `find()` is a string method, so we start by giving the string we're interested in searching and then attaching the `find()` method to it. If the substring we're looking for is found, we'll get its position in the string we were searching (`mystring.find('ri')` would give us a result of `4`). If the substring isn't found in the string we're searching , the result will be `-1`.
#
# To make what's happening in the next cell clearer, I'm going to break things down into smaller steps and print the output one step at a time before putting it all together in one line.
#
# For now, we'll just use the starting index and a colon with nothing after it to show a feature of slicing in Python: if we provide only a starting index and no ending index, we'll get a substring that begins where we designated and continues to the end of the string.

# %%
#Code cell #14
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    if record.get('100', None) is not None :
      dates = record['100']['d']
      print("record['100']['d'] = " + dates)
      #Find the hyphen
      hyphen_position = dates.find('-')
      #What is hyphen_position, actually?
      print('hyphen_position = ' + str(hyphen_position))

      #Use hyphen position as the starting point of our slice. No ending position
      #means we'll get the remainder of the string
      print('dates[hyphen_position:] = ' + dates[hyphen_position:])

      #Opening indices are inclusive. Add 1 to get rid of the hyphen
      print('dates[hyphen_position+1:] = ' + dates[hyphen_position+1:])

      #One-liner
      print(dates[dates.find('-')+1:])
      print('---------')
# Out:
# record['100']['d'] = 1576-1631.
# hyphen_position = 4
# dates[hyphen_position:] = -1631.
# dates[hyphen_position+1:] = 1631.
# 1631.
# ---------
# record['100']['d'] = 1688-1730.
# hyphen_position = 4
# dates[hyphen_position:] = -1730.
# dates[hyphen_position+1:] = 1730.
# 1730.
# ---------
# record['100']['d'] = 1713 or 14-1773.
# hyphen_position = 10
# dates[hyphen_position:] = -1773.
# dates[hyphen_position+1:] = 1773.
# 1773.
# ---------
# record['100']['d'] = 1687-1734.
# hyphen_position = 4
# dates[hyphen_position:] = -1734.
# dates[hyphen_position+1:] = 1734.
# 1734.
# ---------
# record['100']['d'] = 1654-1727.
# hyphen_position = 4
# dates[hyphen_position:] = -1727.
# dates[hyphen_position+1:] = 1727.
# 1727.
# ---------

# %% [markdown]
# We need to get rid of the period at the end of the string, and there are several different approaches we could take.
# * We could use `find()` again to find the period and use its position as our ending index.
# * We could use an ending index of -1 to go up to (but not including) the last character in the string
# * We could use the `strip()` method to eliminate the period from the string.
#
# Any of those approaches will give us the same result.

# %%
#Code cell #15
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    if record.get('100', None) is not None :
      dates = record['100']['d']
      print('Finding the period as an ending index = ' + \
            dates[dates.find('-')+1:dates.find('.')])
      print('Using -1 as an ending index = ' + dates[dates.find('-')+1:-1])
      print("Using strip('.') = " + dates[dates.find('-')+1:].strip('.'))
      print('----------')
# Out:
# Finding the period as an ending index = 1631
# Using -1 as an ending index = 1631
# Using strip('.') = 1631
# ----------
# Finding the period as an ending index = 1730
# Using -1 as an ending index = 1730
# Using strip('.') = 1730
# ----------
# Finding the period as an ending index = 1773
# Using -1 as an ending index = 1773
# Using strip('.') = 1773
# ----------
# Finding the period as an ending index = 1734
# Using -1 as an ending index = 1734
# Using strip('.') = 1734
# ----------
# Finding the period as an ending index = 1727
# Using -1 as an ending index = 1727
# Using strip('.') = 1727
# ----------

# %% [markdown]
# #### Splitting a string to a list
# So far, all of our approaches have involved finding the hyphen in our string and using its location to slice the string—we've just used a few different methods after that.
#
# If there's a character we know serves as a separator between different parts of a string that we're interested, we can use the `split()` to split the string apart every time we encounter that separator and store the individual components as a list.
#
# As you'll see, lists appear in square brackets with their individual items separated by commas. Because the items in our lists are all strings, each item will appear in single quotation marks. (Note, though, that a list can contain items of different types—strings, numbers, other lists, etc.)

# %%
#Code cell #16
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    if record.get('100', None) is not None :
      date_string = record['100']['d']
      dates = date_string.split('-')
      print(dates)
# Out:
# ['1576', '1631.']
# ['1688', '1730.']
# ['1713 or 14', '1773.']
# ['1687', '1734.']
# ['1654', '1727.']

# %% [markdown]
# Working with the elements of a list is going to look a lot like what we've been doing in getting substrings of longer strings, because items in lists also have indices, and they behave the same way:
#
# * `my_list[1:5]` would get the second through fifth items in a list
# * `my_list[2:]` would return everything from the third item of the list to the end
# * `my_list[:-1]` would return all of the items except the last
#
# Let's have a look at the structure of a list using `enumerate()` (which explicitly returns list indices as well as values).
#
# * First, we'll print the list, itself, again.
# * Then we'll iterate through the enumerated list using a `for` loop to show the `index` and `value` of each item in the list.
# * Finally, we'll print out each item in the list individually using its list index

# %%
#Code cell #17
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    if record.get('100', None) is not None :
      date_string = record['100']['d']
      dates = date_string.split('-')
      print(dates)
      #Note: another for loop
      for index, value in enumerate(dates) :
        print(str(index) + ': ' + value)
      print(dates[0])
      print(dates[1])
      print('----------')
# Out:
# ['1576', '1631.']
# 0: 1576
# 1: 1631.
# 1576
# 1631.
# ----------
# ['1688', '1730.']
# 0: 1688
# 1: 1730.
# 1688
# 1730.
# ----------
# ['1713 or 14', '1773.']
# 0: 1713 or 14
# 1: 1773.
# 1713 or 14
# 1773.
# ----------
# ['1687', '1734.']
# 0: 1687
# 1: 1734.
# 1687
# 1734.
# ----------
# ['1654', '1727.']
# 0: 1654
# 1: 1727.
# 1654
# 1727.
# ----------

# %% [markdown]
# Our `dates` lists only have two items, of course. But we can get each item in the list by using its index. In the cell below, I've split the `date_string` to create a `dates` list. Fill in the code to assign items from the `dates` list to two new variables (`birth_year` and `death_year`).

# %%
#Code cell #18
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    if record.get('100', None) is not None :
      author_name = record['100']['a']
      date_string = record['100']['d']
      dates = date_string.split('-')
      #Assign values to the variables birth_year and death_year, using the list index of
      #the appropriate item in the dates list
      birth_year =
      death_year =
      print(author_name)
      print('--Birth year: ' + birth_year)
      print('--Death year: ' + death_year)

# %% [markdown]
# #### Solution
# If you're having trouble, click here to reveal a solution.

# %%
#Suggestion code cell 2
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    if record.get('100', None) is not None :
      author_name = record['100']['a']
      date_string = record['100']['d']
      dates = date_string.split('-')
      #Assign values to the variables birth_year and death_year, using the list index of
      #the appropriate item in the dates list
      birth_year = dates[0]
      #Let's go ahead and remove the period from the end of the death year now,
      #rather than having to do it in a second step.
      death_year = dates[1].rstrip('.')
      print(author_name)
      print('--Birth year: ' + birth_year)
      print('--Death year: ' + death_year)
# Out:
# Davila, Arrigo Caterino,
# --Birth year: 1576
# --Death year: 1631
# Holland, Richard,
# --Birth year: 1688
# --Death year: 1730
# Hasledine, William,
# --Birth year: 1713 or 14
# --Death year: 1773
# Clarke, John,
# --Birth year: 1687
# --Death year: 1734
# Spinckes, Nathaniel,
# --Birth year: 1654
# --Death year: 1727

# %% [markdown]
# ### You thought we were pretty much in the clear at this point, didn't you?
# So, that's been taking shape nicely: we know how to get publication years from the 008 field without having to get into any messiness with Roman numerals or anything in the 260|c field, and we have several different ways to isolate death years in the 100|d field.
#
# Let's have a look at a different subset of our MARC records, though, because there are some more wrinkles we're going to have to deal with.

# %%
#Code cell #19
with open(directory_path + '2023_d1_estc_bowyer_problem_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    if record.get('100', None) is not None :
      author_name = record['100']['a']
      #A new wrinkle in this particular set, and a different bit of PyMarc...
      if record.get('100', None).get('c', None) is not None :
        author_name += ' ' + record['100']['c']
      date_string = record['100']['d']
      print(author_name + ' (' + date_string + ')')
# Out:
# Cowper, Ashley, (d. 1788.)
# White, John, (ca. 1685-1755.)
# De-La-Cour, James, (1709-ca. 1785.)
# Wright, J. (fl. 1720-1744.)
# Ogilby, William, (b. ca. 1713.)
# White, Stephen, (b. 1696 or 7.)
# Fauques, Marianne-Agnès Pillement, dame de, (ca. 1720-ca. 1777.)
# Buckingham, John Sheffield, Duke of, (1648-1720 or 21.)

# %% [markdown]
# Oh boy. Some of these dates fields are going to present problems for us. We know when Ashley Cooper died, at least, even if we don't know when he was born. We know *that* John Sheffield, Duke of Buckingham died, but there's some ambiguity about exactly when. But we only have birth years for William Ogilby and Stephen White. We have birth and death years for Marianne Agnès Pillement Fauques, but they're both approximate. And J. Wright only gets a "fl." How much confidence can we have in those dates as a guide to his/their lifespan?

# %% [markdown]
# ### Introducing Regular Expressions
# Regular expressions provide us with a way for searching for *patterns* of text, even if we don't know the specific form that the text will take.
#
# Consider US phone numbers, for example, which often take the form of (xxx) xxx-xxxx. A phone number should only include numerical characters, and not letters. So if you wanted to detect telephone numbers in a document, you would look for any continuous string of 14 characters that followed the pattern:
#
# * Open parenthesis
# * Three digits (0-9)
# * A space
# * Three digits (0-9)
# * A hyphen
# * Four digits (0-9)
#
# Written as a regular expression, that might take the form:
# > `'\([0-9]{3}\)\s[0-9]{3}\-[0-9]{4}'`
#
# It looks like there's a lot going on there, but it's really not so bad.
#
# This regular expression starts with a backwards slash because certain characters—including parentheses—have special meanings in regular expressions, so when we actually want to find those characters, we need to make sure that our regular expression evaluates them as text, and not as part of the regular expression. (A good example in this regular expresison is the hyphen. Note how there's a hyphen each time we see `0-9`, for example. *Those* hyphens means "in the range of zero to nine." When we come to the hyphen in the middle of the phone number, we need to "escape" it so that our regular expression will look for a hyphen character).
#
# The square brackets enclose sets of characters that *could* appear in the pattern we're looking for. In this case, that's just `[0-9]`, but we could also see things like:
# * `[A-Z]` (upper-case letters)
# * `[a-z]` (lower-case letters)
# * `[A-Za-z0-9]` (any mix of upper-case letters, lower-case letters, and numbers
# * `[cho]` (lower-case letters c, h, or o, specifically)
#
# There are other special patterns that we may encounter this week, but rather than getting into it all now, we'll just try to explain them as they come up.
#
# Regular expressions can be *extremely* useful, but also kind of confusing. We've provided a handout with a crash course on regular expressions which you might find helpful, and there are also lots of resources available online to help you master them. (Especially helpful are interactive sites like [RegEx101](https://regex101.com) and [RegExr](https://regexr.com).)
#
# Regular expressions can get pretty complex and confusing, but sometimes fairly simple ones will get the job done.

# %% [markdown]
# #### Dealing with unhelpful date fields
# For our purposes, there are a few different patterns that are going to spell different kinds of trouble (roughly in descending order of severity):
# * Any date field that begins with "b." (There's no death year. We can't use this at all.)
# * Any date field that begins with "fl." (Those aren't necessarily real dates. We shouldn't use these.)
# * Any date field that contains "ca."
#   - If it's expressing approximation about the birth year (i.e., before the hyphen), we might be able to use it.
#   - If it's expressing approximation about the death date (i.e., after the hyphen), we can't use it.
# * Any date field that contains "or"
#   - If it's expressing a choice between birth years, but the death year is solid, we're okay with it
#   - If the birth year is solid, but the death year is uncertain, we're less okay with it
# * Any date field beginning with "d." (At least we have a death year, though we should be on the lookout for other tricky bits like "d. ca. 1778"  or "d. 1750 or 51")
#
# Rather than trying to explain the regular expressions and control structures here, I'll add comments to the code to explain things as we go.
#
# Note that I'm using `re.compile()` to define my regular expressions. I could simply write the regular expressions in my control structures, but I prefer to compile them first for two reasons:
# 1. It strikes me as usually more readable use a variable name as the first argument in `re.search()` or `re.findall()`, rather than a potentially gnarly regular expression.
# 2. It allows me to reuse the same regular expression in different places, if need be.

# %%
#Code cell 20
#We need to import Python's re (Regular Expression) library to be able to work
#with regular expressions
import re

#Compile a regular expression to match a series of four digits
#(equivalent to [0-9]{4})
year_pattern = re.compile(r'\d{4}')

#Compile a regular expression to match strings with starting with "b." or "fl."
#(any combination of one or two of the characters b, f, or l, optionally
#followed by a period); OR (the "|" signals alternatives) including a hyphen,
#optionally followed by a space, followed by the characters "ca", optionally
#followed by a period.
born_flourished_cadeath = re.compile(r'^[bfl]{1,2}\.?|\-\s?ca\.?')

#Compile a regular expression to match any string starting with "d", optionally
#followed by a period.
died = re.compile(r'^d\.?')

#Compile a regular expression to match any string with "or" appearing after a
#hyphen (that is, a hyphen followed by one or more character of any kind, followed
#by a space, the characters "or" and another space).
ordeath = re.compile(r'\-.+\sor\s')

with open(directory_path + '2023_d1_estc_bowyer_problem_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    if record.get('100', None) is not None :
      author_name = record['100']['a']
      date_string = record['100']['d']
      print(author_name + ' (' + date_string + ')')
      #Look for occurrences of the year pattern (there should be either one or
      # two,but some records may not have valid years [e.g. "17th-century"])
      if re.findall(year_pattern, date_string) is not None :

        #If the born_flourished_cadeath pattern is found (or, I guess, isn't
        #not found), we can't use this record.
        if re.search(born_flourished_cadeath, date_string) is not None :
          print('--Cannot use this date field.')


        #If the died pattern is found...
        elif re.search(died, date_string) is not None :
          #Print the first (i.e. only) year
          print('--' + re.findall(year_pattern, date_string)[0])

        #If the ordeath pattern is found...
        elif re.search(ordeath, date_string) is not None :
          #Print the second (i.e., death) year
          print('--' + re.findall(year_pattern, date_string)[1])

        #In any other case, we should be dealing with a standard yyyy-yyyy pattern
        #So find all instances of the year_pattern and print the second one.
        else :
          print('--' + re.findall(year_pattern, date_string)[1])

      else :
        print('No valid dates')
# Out:
# Cowper, Ashley, (d. 1788.)
# --1788
# White, John, (ca. 1685-1755.)
# --1755
# De-La-Cour, James, (1709-ca. 1785.)
# --Cannot use this date field.
# Wright, J. (fl. 1720-1744.)
# --Cannot use this date field.
# Ogilby, William, (b. ca. 1713.)
# --Cannot use this date field.
# White, Stephen, (b. 1696 or 7.)
# --Cannot use this date field.
# Fauques, Marianne-Agnès Pillement, (ca. 1720-ca. 1777.)
# --Cannot use this date field.
# Buckingham, John Sheffield, (1648-1720 or 21.)
# --1720

# %% [markdown]
# #### Once more, with *functions*!
# This kind of checking a string to see if it meets certain conditions is the *kind* of thing we might want to be able to do in other contexts—it's a candidate for what Carl called **local code reuse**. Perhaps we could use the same logic to search added entry subject fields to see which books were written *about* living vs. dead people in a given year, for instance. It would be a shame to have to type all of that code all over again just because we wanted to check a 700 field instead of a 100 field.
#
# I'll write this as a function that accepts one argument (I'm expecting a string of text). Everything else in this cell should look familiar from the previous cell. What this cell does, though, is to take the procedures from the previous cell and give them a name that can be called, as we'll see in the next cell.
#
# (**Note:** You need to run this cell for the `get_death_year` function to be available elsewhere in the notebook, but you won't see any output.)

# %%
#Code cell 21
def get_death_year(date_string) :
  year_pattern = re.compile(r'\d{4}')
  born_flourished_cadeath = re.compile(r'^[bfl]{1,2}\.?|\-\s?ca\.?')
  died = re.compile(r'^d\.?')
  ordeath = re.compile(r'\-.+\sor\s')

  if re.search(year_pattern, date_string) is None :
    #We don't just want to print results now, we want to process a string and
    #produce a result. If there are no valid years, we need a way to return
    #a result of None.
    result = None

  elif re.search(born_flourished_cadeath, date_string) is not None :
    #If we can't provide a *usable* year, we should also return a result of None
    result = None

  elif re.search(died, date_string) is not None :
    result = re.findall(year_pattern, date_string)[0]

  elif re.search(ordeath, date_string) is not None :
    result = re.findall(year_pattern, date_string)[1]

  else :
    result = re.findall(year_pattern, date_string)[1]

  return result

# %% [markdown]
# In this cell, I still have to read the MARC file and identify what field I want to check for a valid death year. But once I have that string, I pass it as an argument to the `get_death_year` function and receive a result.

# %%
#Code cell 22
with open(directory_path + '2023_d1_estc_bowyer_problem_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    if record.get('100', None) is not None:
      author_name = record['100']['a']
      date_string = record['100']['d']

      #Call the get_death_year function, passing date_string as the argument
      death_year = get_death_year(date_string)

      #Depending on the result that the get_death_year function returns, do
      #something
      if death_year is not None :
        print(author_name + ' died in ' + death_year)
      else :
        print('No death year for ' + author_name)
# Out:
# Cowper, Ashley, died in 1788
# White, John, died in 1755
# No death year for De-La-Cour, James,
# No death year for Wright, J.
# No death year for Ogilby, William,
# No death year for White, Stephen,
# No death year for Fauques, Marianne-Agnès Pillement,
# Buckingham, John Sheffield, died in 1720

# %% [markdown]
# Now that `get_death_year` is available as a function, I can call it again when opening a different file without having to rewrite (or copy and paste) the code.

# %%
#Code cell 23
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    if record.get('100', None) is not None :
      #You know, let's change around with this author name a little...
      author_name = record['100']['a'].rstrip(',')
      author_name_parts = author_name.split(', ')
      author_name = author_name_parts[1] + ' ' + author_name_parts[0]
      date_string = record['100']['d']
      death_year = get_death_year(date_string)
      if death_year is not None :
        print(author_name + ' died in ' + death_year)
      else :
        print('No death year for ' + author_name)
# Out:
# Arrigo Caterino Davila died in 1631
# Richard Holland died in 1730
# William Hasledine died in 1773
# John Clarke died in 1734
# Nathaniel Spinckes died in 1727

# %% [markdown]
# ## Okay, we're ready to get going, but first a word about data types...
# At this point, we're able to get publication years from the 008 field and we have a function for finding a valid death year, if there is one. There's just one thing that ought to give us pause: we've been treating all of these values simply as strings of characters, but while we recognize "1773" as a number, the computer doesn't necessarily know that we mean the integer 1,773, rather than just a sequence of the typographical characters "1", "7", "7", and "3".

# %%
#Code cell 24
with open(directory_path + '2023_d1_estc_bowyer_sample.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    pub_year = record['008'].data[7:11]
    print('Publication year: ' + pub_year)
    print(type(pub_year))
# Out:
# Publication year: 1758
# <class 'str'>
# Publication year: 1728
# <class 'str'>
# Publication year: 1733
# <class 'str'>
# Publication year: 1767
# <class 'str'>
# Publication year: 1710
# <class 'str'>
# Publication year: 1743
# <class 'str'>

# %% [markdown]
# Up to now, this hasn't really been a problem for us because we've just been printing things to the screen. (Though you may have noticed me silently using `str()` to change integers into strings so that they could be printed, back in code cells #14 and #17.)
#
# But if we want to perform a mathematical operation—like deciding whether one year is greater or less than another, we need to be working with actual numbers.

# %%
#Code cell 25
with open(directory_path + '2023_d1_estc_bowyer_full.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    print(record['001'].data)
    #Get a substring from MARC field 008 and convert it to an integer
    pub_year = int(record['008'].data[7:11])
    if record.get('100', None) is not None :
      author_name = record['100']['a'].rstrip(',')
      #Just in case some records don't have a date for the author, at all,
      #as can happen with ancient authors as well as pseudonymous ones.
      if record.get('100', None).get('d', None) is not None :
        date_string = record['100']['d']
        death_year = get_death_year(date_string)
        if death_year is not None :
          #Convert the death_year to an integer
          death_year = int(death_year)
          if death_year > pub_year :
            print(author_name + ' died in ' + str(death_year) + ', and so was alive in ' + str(pub_year))
          elif death_year == pub_year :
            print(author_name + ' died in the same year the work was published. Need more information.')
          else :
            print(author_name + ' died in ' + str(death_year) + ', and so was already dead by ' + str(pub_year))
      else :
        print('No dates for ' + author_name)
# Out:
# Streaming output truncated to the last 5000 lines.
# T32184
# T32228
# Girard, Jean-Baptiste died in 1733, and so was alive in 1731
# T32229
# Wynne, William died in 1765, and so was alive in 1723
# T32261
# Potter, John died in 1747, and so was alive in 1720
# T32285
# Powell, W. S. died in 1775, and so was alive in 1757
# T32337
# No dates for Perlin, Étienne.
# T3248
# Butts, Robert died in 1748, and so was alive in 1737
# T32614
# Mason, William died in 1797, and so was alive in 1752
# T32616
# Mason, William died in 1797, and so was alive in 1752
# T32629
# Mallet, David died in 1765, and so was alive in 1763
# T3272
# Monoux, Lewis died in 1771, and so was alive in 1751
# T32728
# Sharp, Thomas died in 1758, and so was alive in 1730
# T32746
# Whiston, William died in 1752, and so was alive in 1736
# T32798
# T32811
# Keate, George died in 1797, and so was alive in 1762
# T32887
# Manningham, Thomas died in 1722, and so was alive in 1721
# T33034
# Wotton, William died in 1727, and so was already dead by 1734
# T33053
# Rock died in 1774, and so was alive in 1745
# T33212
# T33221
# T33222
# T33269
# Maittaire, Michael died in 1747, and so was alive in 1711
# T33276
# Harley, Edward died in 1735, and so was alive in 1724
# T33283
# T33287
# Nixon, John died in 1777, and so was alive in 1755
# T33317
# Pagett, Thomas Catesby died in 1742, and so was alive in 1735
# T33318
# Pagett, Thomas Catesby died in 1742, and so was alive in 1735
# T33319
# Pagett, Thomas Catesby died in 1742, and so was alive in 1735
# T33393
# Oldisworth, William died in 1734, and so was alive in 1711
# T33447
# Kirkland, Thomas died in 1798, and so was alive in 1767
# T33469
# Dennis, John died in 1734, and so was alive in 1711
# T33483
# Grabe, Joannes Ernestus died in 1711, and so was already dead by 1712
# T33528
# Whitefield, George died in 1770, and so was alive in 1738
# T33529
# Whiston, William died in 1752, and so was alive in 1740
# T33633
# Fénelon, François de Salignac de La Mothe- died in 1715, and so was already dead by 1747
# T33848
# Watson, William died in 1787, and so was alive in 1746
# T33873
# Brown, John died in 1766, and so was alive in 1758
# T33912
# T33974
# D'Urfey, Thomas died in 1723, and so was already dead by 1735
# T34024
# Whitefield, George died in 1770, and so was alive in 1739
# T34025
# Whitefield, George died in 1770, and so was alive in 1739
# T34050
# No dates for Private person.
# T34128
# T34142
# T34144
# T34281
# Bradley, Richard died in 1732, and so was alive in 1730
# T34412
# Arnald, Richard died in 1756, and so was already dead by 1760
# T34413
# Arnald, Richard died in 1756, and so was alive in 1748
# T34414
# Arnald, Richard died in 1756, and so was alive in 1744
# T34415
# Arnald, Richard died in 1756, and so was alive in 1752
# T34421
# Martin, David died in 1721, and so was alive in 1719
# T34423
# Mann, Nicholas died in 1753, and so was alive in 1747
# T34424
# Stuart, James died in 1788, and so was alive in 1771
# T34496
# Brown, John died in 1766, and so was alive in 1763
# T34498
# Brown, John died in 1766, and so was alive in 1763
# T34515
# No dates for R--er, Ab-l.
# T34594
# Blackrie, Alexander died in 1772, and so was alive in 1771
# T34660
# Robinson, Bryan died in 1754, and so was alive in 1748
# T34674
# T34682
# Douglas, John died in 1743, and so was alive in 1739
# T34754
# King, William died in 1729, and so was alive in 1728
# T34764
# Salwey, John died in 1759, and so was alive in 1722
# T34789
# Fiddes, Richard died in 1725, and so was alive in 1721
# T34861
# Cibber, Colley died in 1757, and so was alive in 1718
# T34888
# Brett, Thomas died in 1744, and so was alive in 1717
# T34941
# Lee, Nathaniel died in 1692, and so was already dead by 1734
# T34984
# Du Port, François died in 1624, and so was already dead by 1765
# T35061
# Middleton, John died in 1744, and so was alive in 1730
# T35076
# Wells, Edward died in 1727, and so was alive in 1710
# T35240
# Warburton, William died in 1779, and so was alive in 1745
# T35279
# Sacheverell, Henry died in 1724, and so was alive in 1713
# T35280
# Sacheverell, Henry died in 1724, and so was alive in 1713
# T353
# Burton, Thomas died in 1731, and so was alive in 1713
# T35360
# Potter, R. died in 1804, and so was alive in 1749
# T35559
# Orrery, John Boyle died in 1762, and so was alive in 1741
# T35637
# Collier, Jeremy died in the same year the work was published. Need more information.
# T35717
# T35719
# T35724
# Middleton, John died in 1744, and so was alive in 1732
# T35841
# Whitefield, George died in 1770, and so was alive in 1738
# T35892
# Parker, William died in 1802, and so was alive in 1752
# T36078
# Whitefield, George died in 1770, and so was alive in 1738
# T36289
# Ellis, John died in 1776, and so was alive in 1774
# T36321
# Whiston, William died in 1752, and so was alive in 1748
# T36335
# Salmon, N. died in 1742, and so was alive in 1740
# T36572
# Somervile, William died in 1742, and so was alive in 1740
# T36583
# No dates for Homer.
# T36625
# Synge, Edward died in 1741, and so was alive in 1737
# T36657
# Savage, John died in 1747, and so was alive in 1730
# T36944
# Shepheard, James died in the same year the work was published. Need more information.
# T36984
# No dates for Homer.
# T36993
# Turner, Edward died in 1766, and so was alive in 1739
# T37023
# T37059
# No dates for Hall, Fayrer.
# T373
# T37326
# Whitefield, George died in 1770, and so was alive in 1738
# T37480
# Swift, Jonathan died in 1745, and so was alive in 1732
# T37853
# Warburton, William died in 1779, and so was alive in 1747
# T37897
# Wilson, Benjamin died in 1788, and so was alive in 1764
# T37945
# Hoadly, Benjamin died in 1761, and so was alive in 1757
# T37947
# Stanhope, George died in 1728, and so was alive in 1718
# T37987
# Fiddes, Richard died in 1725, and so was alive in 1721
# T38024
# Clarke, Edward died in 1786, and so was alive in 1755
# T38124
# Arnall, William died in 1700, and so was already dead by 1730
# T38203
# Smith, John died in 1775, and so was alive in 1752
# T38362
# No dates for Fuller, P.
# T38393
# No dates for Some Oxford Electors.
# T38431
# Lowth, Robert died in 1787, and so was alive in 1766
# T38440
# Lowth, Robert died in 1787, and so was alive in 1766
# T38441
# Lowth, Robert died in 1787, and so was alive in 1766
# T38454
# No dates for Gentleman of Oxford.
# T38472
# Hammond, Robert died in 1654, and so was already dead by 1764
# T38509
# T38511
# T38512
# T38518
# T38534
# Bolingbroke, Henry St. John died in 1751, and so was alive in 1749
# T38782
# Jortin, John died in 1770, and so was alive in 1748
# T38792
# Steele, Richard died in 1729, and so was alive in 1717
# T38800
# Garrick, David died in 1779, and so was alive in 1743
# T38801
# Garrick, David died in 1779, and so was alive in 1743
# T38807
# Garrick, David died in 1779, and so was alive in 1741
# T38905
# Etherege, George died in 1691, and so was already dead by 1735
# T39440
# Wagstaffe, William died in 1725, and so was already dead by 1726
# T39445
# Swift, Jonathan died in 1745, and so was already dead by 1746
# T39454
# Swift, Jonathan died in 1745, and so was alive in 1711
# T39459
# Swift, Jonathan died in 1745, and so was alive in 1738
# T39467
# Swift, Jonathan died in 1745, and so was already dead by 1748
# T39468
# Swift, Jonathan died in the same year the work was published. Need more information.
# T39470
# Swift, Jonathan died in 1745, and so was alive in 1730
# T39474
# Swift, Jonathan died in 1745, and so was alive in 1730
# T39476
# Swift, Jonathan died in 1745, and so was already dead by 1748
# T39479
# Swift, Jonathan died in 1745, and so was already dead by 1748
# T39624
# Stukeley, William died in 1765, and so was alive in 1742
# T39630
# Lupton, William died in 1726, and so was alive in 1724
# T39631
# Lupton, William died in 1726, and so was alive in 1724
# T39679
# Clarke, Joseph died in 1758, and so was alive in 1721
# T39680
# Whitefield, George died in 1770, and so was alive in 1738
# T39681
# Whitefield, George died in 1770, and so was alive in 1738
# T39700
# No dates for Smith, George
# T39702
# Warburton, William died in 1779, and so was alive in 1746
# T39704
# Reeves, William died in 1726, and so was alive in 1712
# T3991
# Stebbing, Henry died in 1763, and so was alive in 1730
# T39936
# T3997
# Hammond, Anthony died in 1738, and so was alive in 1731
# T40057
# Derrick, Samuel died in 1769, and so was alive in 1751
# T4011
# Hume, David died in 1776, and so was alive in 1757
# T40147
# No dates for Boval, Frances.
# T40172
# Arnall, William died in 1700, and so was already dead by 1730
# T40173
# Arnall, William died in 1700, and so was already dead by 1730
# T40194
# Addison, Joseph died in 1719, and so was alive in 1716
# T40283
# T40294
# Middleton, Conyers died in 1750, and so was alive in 1719
# T40295
# Middleton, Conyers died in 1750, and so was alive in 1719
# T40296
# Middleton, Conyers died in 1750, and so was alive in 1719
# T40380
# T40548
# Dodsley, Robert died in 1764, and so was alive in 1761
# T40740
# Laurence, John died in 1732, and so was alive in 1716
# T40767
# T40768
# T40778
# Martin, David died in 1721, and so was already dead by 1722
# T40794
# Piers, Sarah died in 1720, and so was alive in 1714
# T40810
# T40850
# Baxter, William died in 1723, and so was alive in 1719
# T40888
# Gyles, Fletcher died in 1741, and so was alive in 1737
# T40889
# Gyles, Fletcher died in 1741, and so was alive in 1738
# T41103
# Wright, S. died in 1746, and so was alive in 1715
# T41173
# T41189
# Delany, Patrick died in 1768, and so was alive in 1732
# T41192
# Whiston, William died in 1752, and so was alive in 1738
# T41206
# Sherlock, Thomas died in 1761, and so was alive in 1718
# T4124
# Cleland, John died in 1789, and so was alive in 1766
# T4130
# Cleland, John died in 1789, and so was alive in 1769
# T4131
# Cleland, John died in 1789, and so was alive in 1768
# T4137
# T41408
# Gastrell, Francis died in the same year the work was published. Need more information.
# T4141
# T4143
# T4145
# T41645
# Taylor, John died in 1766, and so was alive in 1730
# T41729
# Burke, Edmund died in 1797, and so was alive in 1769
# T41730
# Burke, Edmund died in 1797, and so was alive in 1769
# T41776
# T41802
# Owen, Henry died in 1795, and so was alive in 1764
# T41907
# Blackburne, Francis died in 1787, and so was alive in 1768
# T42028
# Shepherd, R. died in 1809, and so was alive in 1761
# T42031
# No dates for Horace.
# T42046
# No dates for Horace.
# T42048
# No dates for Horace.
# T42050
# No dates for Horace.
# T42091
# Melmoth, William died in 1799, and so was alive in 1735
# T42102
# Whitefield, George died in 1770, and so was alive in 1738
# T42122
# Broughton, John died in 1720, and so was alive in 1714
# T42125
# Browne, Isaac Hawkins died in 1760, and so was alive in 1754
# T42137
# T42145
# Conway, Henry Seymour died in 1795, and so was alive in 1758
# T42162
# Congreve, William died in 1729, and so was already dead by 1735
# T42217
# Holdsworth, E. died in 1746, and so was alive in 1742
# T42255
# Burke, Edmund died in 1797, and so was alive in 1773
# T42268
# Frowde, Philip died in 1738, and so was alive in 1731
# T42287
# Falconet, Etienne died in 1791, and so was alive in 1777
# T42369
# Mangey, Thomas died in 1755, and so was alive in 1719
# T42491
# Parker, William died in 1802, and so was alive in 1753
# T42492
# Parker, William died in 1802, and so was alive in 1753
# T42495
# Akenside, Mark died in 1770, and so was alive in 1763
# T42538
# Smith, Edmund died in the same year the work was published. Need more information.
# T42575
# Manningham, Thomas died in 1750, and so was already dead by 1763
# T42637
# T42675
# Chatterton, Thomas died in 1770, and so was already dead by 1777
# T42676
# Chatterton, Thomas died in 1770, and so was already dead by 1777
# T42677
# Chatterton, Thomas died in 1770, and so was already dead by 1778
# T42686
# Barker, Samuel died in 1759, and so was already dead by 1761
# T4277
# No dates for Ford, Randolph.
# T42920
# T4311
# Squire, Francis died in 1750, and so was alive in 1746
# T43113
# Spinckes, Nathaniel died in 1727, and so was alive in 1719
# T4312
# Stanhope, George died in 1728, and so was alive in 1714
# T43126
# Swift, Thomas died in 1752, and so was alive in 1710
# T4313
# Stanhope, George died in 1728, and so was alive in 1714
# T4343
# No dates for [Chapone, Sarah]
# T4468
# T4534
# Warburton, William died in 1779, and so was alive in 1746
# T4622
# Jacob, Hildebrand died in 1739, and so was alive in 1737
# T4694
# Keate, George died in 1797, and so was alive in 1768
# T4696
# Hall-Stevenson, John died in 1785, and so was alive in 1770
# T4706
# Keate, George died in 1797, and so was alive in 1773
# T4738
# Webb, Philip Carteret died in 1770, and so was alive in 1756
# T4750
# Warburton, William died in 1779, and so was alive in 1738
# T4910
# Blackburne, Francis died in 1787, and so was alive in 1769
# T4914
# Taylor, Henry died in 1785, and so was alive in 1772
# T5000
# Wesley, John died in 1791, and so was alive in 1765
# T5045
# Bisse, Thomas died in 1731, and so was alive in 1725
# T5081
# Hewerdine, Thomas died in 1738, and so was alive in 1711
# T5162
# Wotton, William died in 1727, and so was alive in 1723
# T5269
# Jackson, John died in 1763, and so was alive in 1731
# T5271
# T5385
# Pope, Alexander died in 1744, and so was alive in 1717
# T5386
# Pope, Alexander died in 1744, and so was alive in 1717
# T5387
# Pope, Alexander died in 1744, and so was alive in 1717
# T5388
# Pope, Alexander died in 1744, and so was alive in 1717
# T5389
# Pope, Alexander died in 1744, and so was alive in 1717
# T5424
# Pope, Alexander died in 1744, and so was alive in 1743
# T5432
# Pope, Alexander died in 1744, and so was already dead by 1751
# T5433
# Pope, Alexander died in 1744, and so was already dead by 1751
# T5434
# Pope, Alexander died in 1744, and so was already dead by 1753
# T5435
# Pope, Alexander died in 1744, and so was already dead by 1754
# T5437
# Pope, Alexander died in 1744, and so was already dead by 1757
# T5485
# Pope, Alexander died in the same year the work was published. Need more information.
# T5520
# Pope, Alexander died in 1744, and so was already dead by 1769
# T5555
# Pope, Alexander died in 1744, and so was alive in 1742
# T5560
# Pope, Alexander died in 1744, and so was alive in 1743
# T5566
# Pope, Alexander died in 1744, and so was alive in 1719
# T5578
# Pope, Alexander died in 1744, and so was alive in 1721
# T5612
# Pope, Alexander died in the same year the work was published. Need more information.
# T5613
# Pope, Alexander died in 1744, and so was already dead by 1745
# T5614
# Pope, Alexander died in 1744, and so was already dead by 1745
# T5616
# Pope, Alexander died in 1744, and so was already dead by 1746
# T5617
# Pope, Alexander died in 1744, and so was already dead by 1748
# T5618
# Pope, Alexander died in 1744, and so was already dead by 1748
# T5620
# Pope, Alexander died in 1744, and so was already dead by 1749
# T5622
# Pope, Alexander died in 1744, and so was already dead by 1751
# T5630
# Pope, Alexander died in 1744, and so was already dead by 1763
# T5685
# Pope, Alexander died in 1744, and so was alive in 1723
# T5696
# Pope, Alexander died in 1744, and so was alive in 1722
# T5729
# Pope, Alexander died in 1744, and so was alive in 1714
# T5730
# Pope, Alexander died in 1744, and so was alive in 1715
# T5733
# Pope, Alexander died in 1744, and so was alive in 1723
# T5743
# Pope, Alexander died in 1744, and so was alive in 1727
# T5744
# Pope, Alexander died in 1744, and so was alive in 1727
# T5754
# Pope, Alexander died in 1744, and so was alive in 1715
# T5765
# Pope, Alexander died in 1744, and so was alive in 1720
# T5779
# T5780
# T5781
# T5782
# T5916
# Hurd, Richard died in 1808, and so was alive in 1764
# T6289
# Burke, William died in 1798, and so was alive in 1765
# T6299
# Norden, Frederik Ludvig died in 1742, and so was already dead by 1757
# T6379
# T6434
# Warner, Richard died in 1775, and so was alive in 1768
# T6545
# Lupton, William died in 1726, and so was alive in 1720
# T656
# Baker, Samuel died in 1778, and so was alive in 1756
# T657
# Baker, Samuel died in 1778, and so was alive in 1756
# T6620
# Pegge, Samuel died in 1796, and so was alive in 1742
# T663
# Baker, Samuel died in 1778, and so was alive in 1757
# T699
# Stebbing, Henry died in 1763, and so was alive in 1739
# T706
# Swift, Jonathan died in 1745, and so was alive in 1730
# T708
# Wells, Edward died in 1727, and so was already dead by 1738
# T7304
# Stebbing, Henry died in 1763, and so was alive in 1745
# T7315
# Arnald, Richard died in 1756, and so was alive in 1746
# T7316
# Ashton, Thomas died in 1775, and so was alive in 1745
# T749
# Keate, George died in 1797, and so was alive in 1766
# T7876
# Forster, Johann Reinhold died in 1798, and so was alive in 1776
# T792
# Brown, John died in 1766, and so was alive in 1756
# T794
# Brown, John died in 1766, and so was alive in 1755
# T7948
# Gyles, Fletcher died in 1741, and so was alive in 1735
# T7955
# Whiston, John died in 1780, and so was alive in 1738
# T8332
# Squire, Samuel died in 1766, and so was alive in 1745
# T8374
# Bisse, Thomas died in 1731, and so was alive in 1716
# T8375
# Sacheverell, Henry died in 1724, and so was alive in 1714
# T8376
# Bell, George died in 1734, and so was alive in 1713
# T8406
# Bisse, Thomas died in 1731, and so was alive in 1721
# T8583
# Young, Edward died in 1765, and so was alive in 1763
# T867
# Hare, Francis died in 1740, and so was alive in 1720
# T9088
# Berkeley, George died in 1753, and so was alive in 1744
# T9134
# Mead, Richard died in 1754, and so was alive in 1721
# T9145
# Douglass, William died in 1752, and so was alive in 1730
# T9316
# Davis, Charles died in 1755, and so was alive in 1727
# T9519
# Barrington, Shute died in 1826, and so was alive in 1772
# T952
# Thomson, James died in 1748, and so was already dead by 1749
# T9521
# Berkeley, George died in 1753, and so was alive in 1744
# T9522
# Berkeley, George died in 1753, and so was alive in 1747
# T9540
# Prior, Thomas died in 1751, and so was alive in 1746
# T9541
# Prior, Thomas died in 1751, and so was alive in 1746
# T9550
# Yorke, James died in 1808, and so was alive in 1776
# T9554
# T9582
# Marriott, James died in 1803, and so was alive in 1755
# T9614
# Wilkins, David died in 1745, and so was alive in 1722
# T9641
# Mangey, Thomas died in 1755, and so was alive in 1719
# T9657
# Hawkyns, George died in 1749, and so was alive in 1731
# T9676
# Clagett, Nicholas died in 1746, and so was alive in 1714
# T9725
# T149174
# Atterbury, Francis died in 1732, and so was already dead by 1766
# T149176
# No dates for Astruc, John.
# T149306
# T149319
# Bull, George died in 1710, and so was already dead by 1714
# T149340
# Lawson, John died in the same year the work was published. Need more information.
# T149591
# North, Roger died in 1734, and so was already dead by 1742
# T149592
# North, Roger died in 1734, and so was already dead by 1744
# T149594
# Parsons, James died in 1770, and so was alive in 1767
# T149694
# T149733
# Lobb, Theophilus died in 1763, and so was alive in 1741
# T149745
# Lowth, Robert died in 1787, and so was alive in 1767
# T149857
# Hurd, Richard died in 1808, and so was alive in 1777
# T149862
# King, William died in 1712, and so was already dead by 1776
# T149866
# Sawyer, Edmund died in 1759, and so was alive in 1725
# T149867
# No dates for Orosius, Paulus.
# T149946
# Clanricarde, Ulick de Burgh died in 1657, and so was already dead by 1757
# T150024
# T150086
# Watson, Richard died in 1816, and so was alive in 1772
# T150185
# Chishull, Edmund died in 1733, and so was already dead by 1747
# T150186
# Chishull, Edmund died in 1733, and so was already dead by 1747
# T150231
# Saunderson, Nicholas died in 1739, and so was already dead by 1776
# T150535
# Richardson, Jonathan died in 1745, and so was alive in 1722
# T150579
# Castlemaine, Roger Palmer died in 1705, and so was already dead by 1746
# T151042
# Wintringham, Clifton died in 1748, and so was alive in 1733
# T151132
# No dates for Demosthenes.
# T151170
# Wotton, William died in 1727, and so was already dead by 1732
# T151897
# Baxter, William died in 1723, and so was already dead by 1731
# T151974
# Morant, Philip died in 1770, and so was alive in 1766
# T152016
# No dates for Menteith, Robert.
# T152017
# No dates for Menteith, Robert.
# T152101
# Carter, Francis died in 1783, and so was alive in 1777
# T152287
# No dates for Theocritus.
# T152604
# Mulgrave, Constantine John Phipps died in 1792, and so was alive in 1774
# T152719
# Whitby, Daniel died in 1726, and so was alive in 1710
# T152757
# Clayton, Robert died in 1758, and so was alive in 1751
# T152800
# T153051
# Rogers, Charles died in 1784, and so was alive in 1778
# T153174
# T153182
# No dates for Tomlinson, Kellom.
# T153310
# Schrevel, Cornelis died in 1644, and so was already dead by 1774
# T153318
# T153409
# Ashby, George died in 1808, and so was alive in 1774
# T153463
# Selden, John died in 1654, and so was already dead by 1725
# T153464
# Selden, John died in 1654, and so was already dead by 1726
# T153465
# Selden, John died in 1654, and so was already dead by 1726
# T153499
# T153501
# Whiston, William died in 1752, and so was alive in 1741
# T153510
# No dates for Martial.
# T153564
# Swift, Jonathan died in 1745, and so was already dead by 1749
# T153568
# Swift, Jonathan died in 1745, and so was already dead by 1749
# T153699
# T153970
# T154267
# T154272
# T154383
# Willymott, William died in 1737, and so was alive in 1721
# T154423
# La Fontaine, Jean de died in 1695, and so was already dead by 1734
# T154458
# No dates for Herodian.
# T154464
# T154563
# Plukenet, Leonard died in 1706, and so was already dead by 1720
# T154635
# Schrevel, Cornelis died in 1644, and so was already dead by 1725
# T155090
# Swift, Jonathan died in 1745, and so was alive in 1736
# T155111
# Lockman, John died in 1771, and so was alive in 1736
# T155131
# T155209
# T155233
# T155295
# Saunderson, Nicholas died in 1739, and so was already dead by 1771
# T155317
# Voltaire died in 1778, and so was alive in 1752
# T155372
# Campbell, John died in 1775, and so was alive in 1747
# T155565
# Essex, James died in 1784, and so was alive in 1776
# T160183
# Swift, Jonathan died in 1745, and so was alive in 1732
# T160184
# Swift, Jonathan died in 1745, and so was alive in 1732
# T160848
# Thurloe, John died in 1668, and so was already dead by 1742
# T160988
# T160989
# Milles, Thomas died in 1740, and so was alive in 1721
# T161289
# Leslie, Charles died in 1722, and so was alive in 1721
# T162251
# Sclater, William died in 1717, and so was already dead by 1725
# T162310
# Boyer, Abel died in 1729, and so was already dead by 1764
# T162357
# Newcome, John died in 1765, and so was alive in 1720
# T162389
# Wicquefort, Abraham de died in 1682, and so was already dead by 1716
# T162725
# Stebbing, Henry died in 1763, and so was alive in 1739
# T162792
# Randolph, Thomas died in 1783, and so was alive in 1745
# T162851
# Stebbing, Henry died in 1763, and so was alive in 1757
# T162912
# T164212
# Nelson, Robert died in 1715, and so was already dead by 1762
# T164215
# Nelson, Robert died in 1715, and so was alive in 1710
# T164216
# Nelson, Robert died in 1715, and so was alive in 1713
# T164218
# Nelson, Robert died in 1715, and so was already dead by 1744
# T164230
# Boyer, Abel died in 1729, and so was already dead by 1750
# T164241
# Bowyer, William died in 1777, and so was alive in 1772
# T164852
# Nelson, Robert died in 1715, and so was already dead by 1739
# T164921
# Fielding, Henry died in 1754, and so was alive in 1743
# T165190
# No dates for Aristides, Aelius.
# T165283
# No dates for Lover of his country.
# T165384
# Synge, Edward died in 1741, and so was alive in 1723
# T165405
# Walpole, Horatio Walpole died in 1757, and so was alive in 1752
# T165508
# Astell, Mary died in 1731, and so was alive in 1717
# T165669
# Drelincourt, Charles died in 1669, and so was already dead by 1724
# T165758
# Armstrong, John died in 1779, and so was alive in 1758
# T166205
# Kennett, White died in 1728, and so was alive in 1718
# T166269
# Synge, Edward died in 1741, and so was already dead by 1744
# T166270
# Synge, Edward died in 1741, and so was already dead by 1746
# T166297
# Feijóo y Montenegro, Benito Jerónimo died in 1764, and so was alive in 1760
# T166325
# Nelson, Robert died in 1715, and so was already dead by 1723
# T166331
# Nelson, Robert died in 1715, and so was already dead by 1750
# T166911
# Synge, Edward died in 1741, and so was already dead by 1744
# T167520
# Voltaire died in 1778, and so was alive in 1755
# T167567
# Wesley, John died in 1791, and so was alive in 1738
# T167601
# No dates for Homer.
# T167728
# Synge, Edward died in 1741, and so was already dead by 1757
# T167768
# T167769
# T167923
# T168029
# Gyles, Fletcher died in 1741, and so was alive in 1731
# T168032
# Gyles, Fletcher died in 1741, and so was alive in 1734
# T168127
# Gyles, Fletcher died in 1741, and so was alive in 1733
# T168195
# Gyles, Fletcher died in 1741, and so was alive in 1733
# T168371
# Place, Conyers died in 1738, and so was alive in 1721
# T168549
# Mangey, Thomas died in 1755, and so was alive in 1720
# T168658
# No dates for Pocock, Thomas.
# T168836
# Essex, James died in 1784, and so was alive in 1775
# T168843
# Mangey, Thomas died in 1755, and so was alive in 1718
# T169573
# No dates for Terence.
# T169980
# T170029
# T170391
# T170428
# T170430
# T170659
# No dates for Cicero, Marcus Tullius.
# T170831
# Richardson, Samuel died in 1761, and so was alive in 1741
# T171209
# Ramsay, Allan died in 1758, and so was alive in 1719
# T171346
# Anson, George Anson died in 1762, and so was alive in 1756
# T171976
# Waterland, Daniel died in 1740, and so was alive in 1732
# T172216
# Conway, Henry Seymour died in 1795, and so was alive in 1758
# T172226
# White, John died in 1755, and so was alive in 1746
# T172400
# Osbeck, Pehr died in 1805, and so was alive in 1771
# T172439
# T172508
# T172688
# No dates for Original subscriber to the infirmary in James-Street, Westminster.
# T172695
# No dates for Dalrymple, James
# T172738
# T172758
# Bayes, Thomas died in 1761, and so was already dead by 1764
# T172801
# Warburton, William died in 1779, and so was alive in 1746
# T173018
# Hoole, Joseph died in 1745, and so was alive in 1724
# T173082
# King, William died in 1763, and so was alive in 1739
# T173425
# Synge, Edward died in 1741, and so was already dead by 1762
# T173447
# White, Thomas died in 1735, and so was alive in 1723
# T173577
# Reeves, William died in 1726, and so was alive in 1714
# T174081
# Parker, William died in 1802, and so was alive in 1757
# T174107
# T174231
# Stanhope, George died in 1728, and so was alive in 1712
# T174256
# Turpin, Richard died in the same year the work was published. Need more information.
# T174488
# T174834
# Perronet, Vincent died in 1785, and so was alive in 1752
# T174943
# Stephens, William died in 1718, and so was alive in 1712
# T175063
# Zinzendorf, Nicolaus Ludwig died in 1760, and so was alive in 1750
# T175064
# Zinzendorf, Nicolaus Ludwig died in 1760, and so was alive in 1751
# T175085
# Anson, George Anson died in 1762, and so was already dead by 1768
# T175095
# Moss, Robert died in 1729, and so was alive in 1712
# T175247
# Farquhar, George died in 1707, and so was already dead by 1718
# T175438
# Lowth, Robert died in 1787, and so was alive in 1774
# T175575
# T175576
# T175609
# No dates for Foreign Minister Residing in Sweden.
# T175614
# Jacob, Hildebrand died in 1739, and so was alive in 1737
# T175639
# Gastrell, Francis died in 1725, and so was alive in 1714
# T175897
# Synge, Edward died in 1741, and so was already dead by 1757
# T176037
# T176076
# Solander, Daniel Charles died in 1782, and so was alive in 1763
# T176372
# T176382
# No dates for La Bléterie, Jean Philippe René de.
# T176420
# No dates for Florus, Lucius Annaeus.
# T176423
# Raper, Matthew died in 1778, and so was alive in 1772
# T176532
# No dates for P. K.
# T176633
# Priestley, Joseph died in 1804, and so was alive in 1772
# T176778
# T177115
# T177447
# No dates for H. B.
# T177845
# Innes, Alexander died in 1742, and so was alive in 1726
# T178179
# No dates for Isocrates.
# T178205
# Atterbury, Francis died in 1732, and so was already dead by 1761
# T178365
# Taswell, William died in 1731, and so was alive in 1722
# T178517
# Sherlock, Thomas died in 1761, and so was alive in 1728
# T178519
# T178734
# Wake, William died in 1737, and so was alive in 1722
# T178858
# Clayton, Robert died in 1758, and so was alive in 1754
# T178923
# No dates for Sayer, Joseph.
# T179152
# Jortin, John died in 1770, and so was already dead by 1772
# T179169
# T179197
# T179208
# No dates for G. O.
# T179464
# South, Robert died in 1716, and so was already dead by 1718
# T179490
# South, Robert died in 1716, and so was already dead by 1718
# T179496
# South, Robert died in 1716, and so was already dead by 1718
# T179676
# No dates for Josephus, Flavius.
# T179782
# Farquhar, George died in 1707, and so was already dead by 1721
# T179796
# Willymott, William died in 1737, and so was alive in 1721
# T179906
# T179976
# T179995
# No dates for Horace.
# T180418
# T181098
# Nelson, Robert died in 1715, and so was already dead by 1718
# T181109
# King, William died in 1712, and so was alive in 1711
# T181692
# Jones, Griffith died in 1761, and so was alive in 1740
# T181712
# T181768
# Owen, Edward died in 1807, and so was alive in 1765
# T182289
# Rogers, John died in 1729, and so was already dead by 1738
# T182903
# Martin, David died in 1721, and so was alive in 1720
# T182917
# Martin, David died in 1721, and so was already dead by 1725
# T183042
# Worthington, John died in 1671, and so was already dead by 1721
# T183110
# T183308
# Strange, John died in 1799, and so was alive in 1769
# T183394
# T183801
# Synge, Edward died in 1741, and so was already dead by 1744
# T183849
# T183850
# T184151
# T184259
# T184380
# Kennedy, John died in 1760, and so was alive in 1756
# T184466
# Massinger, Philip died in 1640, and so was already dead by 1761
# T184758
# Boyer, Abel died in 1729, and so was already dead by 1741
# T184973
# Hickes, George died in 1715, and so was already dead by 1727
# T184996
# No dates for Guarna, Andrea.
# T185214
# T185363
# T185704
# Pococke, Richard died in 1765, and so was alive in 1743
# T185740
# Armstrong, John died in 1779, and so was alive in 1768
# T185741
# Armstrong, John died in 1779, and so was alive in 1765
# T185758
# Powell, W. S. died in 1775, and so was alive in 1760
# T186556
# Ogilby, John died in 1676, and so was already dead by 1719
# T187740
# No dates for Caesar, Julius.
# T187743
# Jones, Griffith died in 1761, and so was alive in 1741
# T188255
# T188630
# Nelson, Robert died in 1715, and so was already dead by 1759
# T189214
# Hasledine, William died in 1773, and so was alive in 1733
# T189276
# Bisse, Thomas died in 1731, and so was alive in 1717
# T189291
# T189524
# T189626
# T189649
# T189664
# T189726
# T189946
# T189950
# T189952
# T190329
# No dates for Cooke, Robert
# T190461
# Carr, John died in 1807, and so was alive in 1764
# T190852
# Middleton, Conyers died in 1750, and so was alive in 1723
# T191031
# Clements, Henry died in 1719, and so was alive in 1717
# T191138
# Nelson, Robert died in the same year the work was published. Need more information.
# T191151
# T191355
# Synge, Edward died in 1741, and so was alive in 1726
# T191492
# No dates for Rose, George
# T191495
# No dates for Rose, George
# T191496
# No dates for Rose, George
# T191833
# T191835
# T191836
# T191837
# T191838
# T191839
# T191841
# T191842
# T192288
# Bell, George died in 1734, and so was alive in 1718
# T192479
# T192931
# Price, Richard died in 1791, and so was alive in 1765
# T193159
# Adams, George died in 1783, and so was alive in 1731
# T193268
# T193484
# Burton, John died in 1771, and so was alive in 1752
# T193565
# Swift, Jonathan died in 1745, and so was already dead by 1765
# T193889
# Boyer, Abel died in 1729, and so was already dead by 1742
# T194322
# Swift, Jonathan died in 1745, and so was already dead by 1765
# T194323
# Swift, Jonathan died in 1745, and so was already dead by 1765
# T194325
# Swift, Jonathan died in 1745, and so was already dead by 1765
# T194327
# Swift, Jonathan died in 1745, and so was already dead by 1765
# T194328
# Swift, Jonathan died in 1745, and so was already dead by 1765
# T194598
# Hodges, Moses died in 1724, and so was alive in 1711
# T194785
# Perronet, Edward died in 1792, and so was alive in 1757
# T195297
# Swift, Jonathan died in 1745, and so was already dead by 1776
# T195741
# No dates for Crispe, Henry.
# T196500
# Morant, Philip died in 1770, and so was alive in 1761
# T196538
# Atterbury, Francis died in 1732, and so was already dead by 1761
# T197175
# T197409
# Voltaire died in 1778, and so was alive in 1728
# T198122
# Stanhope, George died in 1728, and so was alive in 1713
# T198123
# Stanhope, George died in 1728, and so was alive in 1713
# T198234
# T198322
# Folkes, Martin died in 1754, and so was alive in 1745
# T198337
# Bowyer, William died in 1777, and so was alive in 1764
# T199172
# Holinshed, Raphael died in 1580, and so was already dead by 1722
# T199443
# T200309
# Swift, Jonathan died in 1745, and so was alive in 1742
# T200632
# T200694
# Lowth, Robert died in 1787, and so was alive in 1769
# T200826
# Baxter, William died in 1723, and so was alive in 1718
# T200853
# Thou, Jacques Auguste de died in 1617, and so was already dead by 1732
# T200930
# T201005
# Edwards, Thomas died in 1757, and so was alive in 1750
# T201210
# Holinshed, Raphael died in 1580, and so was already dead by 1723
# T201384
# Harris, John died in 1719, and so was already dead by 1747
# T201443
# Morant, Philip died in 1770, and so was alive in 1768
# T201655
# Martin, David died in 1721, and so was alive in 1719
# T201661
# Chambaud, Lewis died in 1776, and so was alive in 1761
# T201957
# Synge, Edward died in 1741, and so was alive in 1722
# T202071
# White, John died in 1755, and so was alive in 1748
# T202082
# Clayton, Robert died in 1758, and so was alive in 1753
# T202083
# Clayton, Robert died in 1758, and so was alive in 1753
# T202142
# Synge, Edward died in 1741, and so was already dead by 1759
# T202642
# Swift, Jonathan died in 1745, and so was alive in 1733
# T202719
# Gyles, Fletcher died in 1741, and so was alive in 1732
# T203697
# Synge, Edward died in 1741, and so was already dead by 1762
# T204615
# Boyer, Abel died in 1729, and so was already dead by 1744
# T205644
# Wright, S. died in 1746, and so was alive in 1723
# T205650
# T205652
# No dates for Dawson, John
# T205972
# White, John died in the same year the work was published. Need more information.
# T206270
# T206430
# Armstrong, John died in 1779, and so was alive in 1756
# T206619
# Byrom, John died in 1763, and so was alive in 1739
# T207261
# Ashburnham, William died in 1797, and so was alive in 1759
# T207369
# No dates for Robertson, Thomas
# T207449
# Fleetwood, Henry died in 1746, and so was alive in 1742
# T207454
# No dates for Beckford, Thomas.
# T207455
# Norfolk, Edward Howard died in 1777, and so was alive in 1742
# T207456
# Murray, Alexander died in 1743, and so was alive in 1742
# T207564
# Cullen, William died in 1790, and so was alive in 1743
# T207589
# No dates for Anderson, William
# T207785
# Annandale, Charlotte Johnston died in 1762, and so was alive in 1755
# T208448
# T208603
# Smith, Roger died in 1736, and so was alive in 1719
# T209571
# T209572
# T209706
# Scott, John died in 1695, and so was already dead by 1730
# T210485
# Synge, Edward died in 1741, and so was already dead by 1757
# T210898
# Synge, Edward died in 1741, and so was alive in 1738
# T211126
# Synge, Edward died in 1741, and so was already dead by 1757
# T212016
# Rowe, Nicholas died in 1718, and so was already dead by 1733
# T212385
# T212389
# T212784
# Hunter, Robert died in 1734, and so was alive in 1726
# T213019
# T213152
# No dates for Mauger, Claude.
# T213230
# White, John died in 1755, and so was alive in 1750
# T213291
# T213294
# T213305
# T213473
# T213708
# Wynne, John died in 1743, and so was alive in 1715
# T214139
# Allix, Pierre died in 1717, and so was alive in 1710
# T214551
# Saltoun of Abernethy, Alexander Fraser died in 1751, and so was alive in 1720
# T214560
# Cockburn, William died in 1782, and so was alive in 1720
# T214567
# Gordon, Robert died in 1772, and so was alive in 1719
# T214586
# No dates for Campbell, John
# T214611
# Stirling, John died in 1757, and so was alive in 1720
# T214787
# Synge, Edward died in 1741, and so was already dead by 1746
# T214815
# Synge, Edward died in 1741, and so was already dead by 1757
# T216327
# Lyttelton, George Lyttelton died in 1773, and so was alive in 1771
# T216461
# T216710
# T217513
# Durand, David died in 1763, and so was already dead by 1778
# T217922
# Synge, Edward died in 1741, and so was already dead by 1761
# T218737
# Swift, Jonathan died in 1745, and so was already dead by 1751
# T219648
# T220098
# T220369
# Pope, Alexander died in 1744, and so was alive in 1742
# T220539
# T220676
# Moray, Charles Stuart died in 1735, and so was alive in 1728
# T220849
# Kennedy, John died in 1760, and so was alive in 1756
# T222422
# T222585
# Grey, Richard died in 1771, and so was alive in 1738
# T222777
# Chaucer, Geoffrey died in 1400, and so was already dead by 1716
# T222939
# T223334
# No dates for Dawson, John
# T223350
# T223811
# T224283
# T224311
# No dates for Ozinde, J. B.
# T224345
# T224407
# Mangey, Thomas died in 1755, and so was alive in 1750
# T224547
# Sawyer, Edmund died in 1759, and so was alive in 1722
# T224567
# Drake, Francis died in 1771, and so was alive in 1732
# T224674
# Gibbs, James died in 1754, and so was alive in 1727
# T224675
# Gibbs, James died in 1754, and so was alive in 1727
# T224677
# Selden, John died in 1654, and so was already dead by 1722
# T224808
# Willis, Browne died in 1760, and so was alive in 1733
# T224841
# T224955
# T225832
# Folkes, Martin died in 1754, and so was alive in 1736
# T225833
# T226277
# T226299
# Pope, Alexander died in 1744, and so was already dead by 1745
# T226383
# No dates for Myself.
# T226435
# Lowth, Robert died in 1787, and so was alive in 1767
# T227120
# T227731
# Cunningham, James died in 1728, and so was alive in 1726
# T227854
# Chishull, Edmund died in 1733, and so was alive in 1728
# T228048
# T228086
# Thomson, James died in 1748, and so was alive in 1730
# T228087
# Thomson, James died in 1748, and so was alive in 1730
# T228088
# Thomson, James died in 1748, and so was alive in 1730
# T228089
# Thomson, James died in 1748, and so was alive in 1730
# T228257
# No dates for Cole, William
# T228519
# Henry, Matthew died in 1714, and so was already dead by 1752
# T229431
# Warner, Richard died in 1775, and so was alive in 1771
# T229562
# Stillingfleet, Benjamin died in 1771, and so was alive in 1741
# T229613
# T229808
# Thomson, James died in 1748, and so was alive in 1730
# T229912
# Nairne, Edward died in 1806, and so was alive in 1771
# T229915
# Jones, W. died in 1749, and so was already dead by 1774
# T230277
# Burgh, William died in 1808, and so was alive in 1780
# T230316
# Thomson, James died in 1748, and so was alive in 1730
# T52941
# T53012
# Shepherd, R. died in 1809, and so was alive in 1759
# T53028
# T53043
# T53105
# T53106
# T53207
# T53264
# Cockburn, W. died in 1739, and so was alive in 1719
# T53265
# Cockburn, W. died in 1739, and so was alive in 1728
# T53390
# No dates for Hall, Fayrer.
# T53403
# Boswell, James died in 1795, and so was alive in 1762
# T53416
# Henley, William died in 1779, and so was alive in 1774
# T53541
# T53547
# T53563
# T53708
# Shakespeare, William died in 1616, and so was already dead by 1734
# T53750
# No dates for Eyles, John
# T53764
# T53873
# Vertot died in 1735, and so was alive in 1728
# T53897
# T53928
# No dates for Smith, George
# T54027
# Cowper, Ashley died in 1788, and so was alive in 1769
# T54034
# Jones, William died in 1794, and so was alive in 1777
# T54171
# Berriman, William died in 1750, and so was alive in 1722
# T54295
# Culm, Benjamin died in 1768, and so was alive in 1751
# T54686
# T54687
# T54707
# Shakespeare, William died in 1616, and so was already dead by 1734
# T54736
# Shakespeare, William died in 1616, and so was already dead by 1734
# T54739
# T54935
# T54999
# Mead, Richard died in 1754, and so was alive in 1747
# T55003
# Mead, Richard died in 1754, and so was alive in 1745
# T55017
# Mead, Richard died in 1754, and so was alive in 1749
# T55124
# Gray, Thomas died in 1771, and so was alive in 1770
# T55267
# T55423
# No dates for Homer.
# T55450
# T55451
# T55452
# T55453
# T55657
# Mead, Richard died in 1754, and so was alive in 1720
# T55658
# Mead, Richard died in 1754, and so was alive in 1720
# T55659
# Mead, Richard died in 1754, and so was alive in 1720
# T55660
# Mead, Richard died in 1754, and so was alive in 1720
# T55661
# Mead, Richard died in 1754, and so was alive in 1722
# T55662
# Mead, Richard died in 1754, and so was alive in 1744
# T55663
# Mead, Richard died in 1754, and so was alive in 1748
# T55701
# Watson, Richard died in 1816, and so was alive in 1772
# T55742
# Blackwall, Anthony died in 1730, and so was alive in 1718
# T55743
# Blackwall, Anthony died in 1730, and so was alive in 1719
# T55939
# Mead, Richard died in 1754, and so was alive in 1723
# T56123
# T56134
# Boerhaave, Herman died in 1738, and so was already dead by 1741
# T56145
# Nicholls, Frank died in 1778, and so was alive in 1740
# T56206
# Manningham, Richard died in 1759, and so was alive in 1726
# T56209
# Manningham, Richard died in 1759, and so was alive in 1726
# T56228
# No dates for T. B.
# T56453
# T56488
# Southerne, Thomas died in 1746, and so was already dead by 1747
# T56654
# Blackall, Offspring died in 1716, and so was already dead by 1723
# T56677
# Blackall, Offspring died in 1716, and so was already dead by 1717
# T56916
# T57008
# T57284
# Jennens, Charles died in 1773, and so was alive in 1772
# T57349
# Morell, Charles died in 1765, and so was alive in 1761
# T57374
# Graves, Richard died in 1804, and so was alive in 1774
# T57462
# T57463
# T57464
# T57465
# T57466
# T57467
# T57468
# T57469
# T57470
# T57471
# T57472
# T57473
# T57474
# T57475
# T57476
# T57477
# T57478
# T57479
# T57480
# T57481
# T57482
# T57483
# T57484
# T57485
# T57486
# T57487
# T57489
# T57490
# T57491
# T57493
# T57494
# T57495
# T57496
# T57497
# T57498
# T57534
# No dates for Gentleman of Gray's-Inn.
# T57644
# Gastrell, Francis died in 1725, and so was alive in 1724
# T57901
# Powell, W. S. died in 1775, and so was alive in 1758
# T57925
# Wake, William died in 1737, and so was alive in 1715
# T57950
# Whitefield, George died in 1770, and so was alive in 1739
# T58108
# Lockman, John died in 1771, and so was alive in 1739
# T58175
# T58215
# T58217
# T58218
# T58219
# T58220
# T58221
# T58222
# T58223
# T58224
# T58225
# T58226
# T58227
# T58228
# T58229
# T58230
# T58231
# T58232
# T58233
# T58234
# T58235
# T58236
# T58237
# T58238
# T58239
# T58240
# T58241
# T58242
# T58243
# T58244
# T58245
# T58246
# T58247
# T58248
# T58249
# T58250
# T58251
# T58252
# T58253
# T58254
# T58255
# T58256
# T58276
# T58277
# Hutton, Charles died in 1823, and so was alive in 1773
# T58278
# Hutton, Charles died in 1823, and so was alive in 1774
# T58279
# Hutton, Charles died in 1823, and so was alive in 1775
# T58280
# Hutton, Charles died in 1823, and so was alive in 1776
# T58281
# Hutton, Charles died in 1823, and so was alive in 1777
# T58339
# T58649
# Smith, Edmund died in 1710, and so was already dead by 1711
# T58739
# No dates for Gentleman of the Middle Temple.
# T58831
# Watson, Richard died in 1816, and so was alive in 1773
# T59032
# No dates for Persius.
# T59233
# Anson, George Anson died in 1762, and so was alive in 1748
# T59239
# Bowers, Thomas died in 1724, and so was alive in 1723
# T59318
# Trebeck, Andrew died in 1759, and so was alive in 1725
# T59323
# Walls, George died in 1727, and so was alive in 1715
# T59335
# Wilmot, Edward died in 1786, and so was alive in 1735
# T59358
# Armstrong, John died in 1779, and so was alive in 1754
# T59368
# No dates for Lover of truth.
# T59521
# T59522
# T59524
# T59525
# T59541
# Lobb, Theophilus died in 1763, and so was alive in 1731
# T59629
# Berington, Simon died in 1755, and so was alive in 1748
# T59669
# Maskelyne, Nevil died in 1811, and so was alive in 1776
# T59670
# Maskelyne, Nevil died in 1811, and so was alive in 1776
# T59671
# Maskelyne, Nevil died in 1811, and so was alive in 1774
# T59672
# Maskelyne, Nevil died in 1811, and so was alive in 1772
# T59673
# Maskelyne, Nevil died in 1811, and so was alive in 1765
# T59674
# Maskelyne, Nevil died in 1811, and so was alive in 1765
# T59675
# Maskelyne, Nevil died in 1811, and so was alive in 1765
# T59683
# Thomson, James died in 1748, and so was already dead by 1773
# T59731
# No dates for Homer.
# T59739
# Switzer, Stephen died in 1745, and so was alive in 1724
# T59740
# Switzer, Stephen died in 1745, and so was alive in 1731
# T59851
# Nelson, Robert died in 1715, and so was already dead by 1726
# T60015
# Armstrong, John died in 1779, and so was alive in 1757
# T60029
# Warner, Richard died in 1775, and so was alive in 1771
# T60030
# Armstrong, John died in 1779, and so was alive in 1758
# T60316
# T60318
# Synge, Edward died in 1762, and so was alive in 1726
# T60325
# T60395
# Gyles, Fletcher died in 1741, and so was alive in 1738
# T60410
# Russell, Richard died in 1759, and so was alive in 1755
# T60448
# Russell, Richard died in 1759, and so was alive in 1755
# T60500
# No dates for Frank, Thomas.
# T60557
# T60731
# Gerard, Alexander died in 1795, and so was alive in 1759
# T60933
# Carr, John died in 1807, and so was alive in 1764
# T60974
# Pluche, Noël Antoine died in 1761, and so was alive in 1743
# T61128
# Heath, Robert died in 1779, and so was alive in 1752
# T61220
# Bisse, Thomas died in 1731, and so was alive in 1716
# T61221
# Bisse, Thomas died in 1731, and so was alive in 1716
# T61222
# Bisse, Thomas died in 1731, and so was alive in 1717
# T61223
# Bisse, Thomas died in 1731, and so was alive in 1720
# T61276
# T61366
# Woodward, John died in 1728, and so was already dead by 1757
# T61388
# T61541
# Grey, Richard died in 1771, and so was alive in 1756
# T61698
# Warner, Ferdinando died in 1768, and so was alive in 1763
# T61796
# Synge, Edward died in 1741, and so was alive in 1737
# T61823
# Gastrell, Francis died in 1725, and so was alive in 1721
# T61824
# Gyllenborg, Carl died in 1746, and so was alive in 1717
# T62020
# T62163
# Hurd, Richard died in 1808, and so was alive in 1759
# T62164
# Hurd, Richard died in 1808, and so was alive in 1760
# T62224
# No dates for Steele, Joshua.
# T62286
# Middleton, Conyers died in 1750, and so was alive in 1732
# T62430
# Brooke, Henry died in 1757, and so was alive in 1740
# T62442
# T62455
# T62458
# Law, William died in 1761, and so was alive in 1719
# T62524
# Gataker, Thomas died in 1769, and so was alive in 1764
# T62918
# T63024
# Edwards, Thomas died in 1757, and so was alive in 1750
# T63026
# Edwards, Thomas died in 1757, and so was alive in 1750
# T63241
# T63255
# Hurd, Richard died in 1808, and so was alive in 1762
# T63341
# Taylor, Brook died in 1731, and so was alive in 1719
# T63611
# Bisse, Thomas died in 1731, and so was alive in 1728
# T63762
# T63768
# Bull, George died in 1710, and so was already dead by 1714
# T63783
# Drake, James died in 1707, and so was already dead by 1717
# T63836
# T63930
# Locke, John died in 1704, and so was already dead by 1721
# T63960
# T64163
# Gray, Charles died in 1782, and so was alive in 1752
# T64272
# Cooper, John Gilbert died in 1769, and so was alive in 1757
# T64325
# Moss, Charles died in 1802, and so was alive in 1744
# T64446
# No dates for Silence, Samuel.
# T64637
# Towne, John died in 1791, and so was alive in 1748
# T64700
# Story, Joseph died in 1757, and so was alive in 1752
# T64790
# Vigor died in 1783, and so was alive in 1775
# T64935
# Dodd, William died in 1777, and so was alive in 1761
# T64977
# Towne, John died in 1791, and so was alive in 1747
# T65079
# Maskelyne, Nevil died in 1811, and so was alive in 1769
# T65262
# Brooke, Frances died in 1789, and so was alive in 1763
# T65285
# Taylor, Jeremy died in 1667, and so was already dead by 1719
# T65365
# Clayton, Robert died in 1758, and so was alive in 1752
# T65382
# No dates for Zinzano.
# T65433
# Drake, Francis died in 1771, and so was alive in 1736
# T65477
# Willis, Browne died in 1760, and so was alive in 1730
# T65478
# Willis, Browne died in 1760, and so was alive in 1750
# T65575
# Bisse, Thomas died in 1731, and so was alive in 1721
# T65816
# Bisse, Thomas died in 1731, and so was alive in 1729
# T65820
# No dates for Deletanville, Thomas.
# T65832
# Grey, Richard died in 1771, and so was alive in 1738
# T66002
# Rowe, Nicholas died in 1718, and so was already dead by 1723
# T66015
# Rowe, Nicholas died in 1718, and so was alive in 1714
# T66018
# Smith, Edmund died in 1710, and so was already dead by 1714
# T66073
# White, John died in 1755, and so was alive in 1749
# T66173
# T66183
# T66228
# T66365
# Brooke, Frances died in 1789, and so was alive in 1777
# T66375
# Riccoboni, Marie Jeanne de Heurles Laboras de Mezières died in 1792, and so was alive in 1764
# T66519
# Gally, Henry died in 1769, and so was alive in 1754
# T66598
# No dates for Bordes de Bercheres, Pierre de.
# T66785
# T66786
# T66860
# Somervile, William died in 1742, and so was already dead by 1743
# T66861
# Somervile, William died in 1742, and so was already dead by 1749
# T66953
# Collier, Jeremy died in 1726, and so was alive in 1713
# T67000
# Culpeper, Nicholas died in 1654, and so was already dead by 1714
# T67008
# Twells, Leonard died in 1742, and so was alive in 1737
# T67009
# Twells, Leonard died in 1742, and so was alive in 1738
# T67011
# Whiston, William died in 1752, and so was alive in 1737
# T67013
# Hutchinson, Thomas died in 1769, and so was alive in 1739
# T67172
# Stanhope, George died in 1728, and so was alive in 1710
# T67229
# White, John died in 1755, and so was alive in 1750
# T67230
# White, John died in 1755, and so was alive in 1748
# T67232
# White, John died in 1755, and so was alive in 1748
# T67240
# White, John died in 1755, and so was alive in 1746
# T67341
# Peyton, Edward died in 1657, and so was already dead by 1731
# T67349
# Adams, John died in 1807, and so was alive in 1773
# T67379
# Blackburne, Francis died in 1787, and so was alive in 1767
# T67380
# Blackburne, Francis died in 1787, and so was alive in 1770
# T67381
# Blackburne, Francis died in 1787, and so was alive in 1766
# T67401
# Somervile, William died in 1742, and so was alive in 1735
# T67492
# Hurd, Richard died in 1808, and so was alive in 1764
# T67544
# T67658
# ...
# T145503
# Echard, Laurence died in 1730, and so was alive in 1718
# T145504
# Echard, Laurence died in 1730, and so was alive in 1718
# T145509
# Whitaker, John died in 1808, and so was alive in 1771
# T145545
# Wallis, John died in 1703, and so was already dead by 1765
# T145553
# Petyt, William died in 1707, and so was already dead by 1739
# T145588
# Ecton, John died in 1730, and so was alive in 1728
# T145634
# Parker, Matthew died in 1575, and so was already dead by 1729
# T145635
# Parker, Matthew died in 1575, and so was already dead by 1729
# T145722
# Bingham, Joseph died in 1723, and so was alive in 1711
# T145734
# No dates for Dionysius
# T145739
# T145756
# Wodhull, Michael died in 1816, and so was alive in 1772
# T145867
# Collier, Jeremy died in 1726, and so was already dead by 1730
# T145868
# Collier, Jeremy died in 1726, and so was already dead by 1738
# T145881
# Evans, Evan died in 1788, and so was alive in 1764
# T145893
# Webb, Philip Carteret died in 1770, and so was alive in 1758
# T145897
# T145903
# Douglass, William died in 1752, and so was already dead by 1755
# T145911
# Morant, Philip died in 1770, and so was alive in 1739
# T146063
# Goldsmith, Oliver died in the same year the work was published. Need more information.
# T146265
# Harris, William died in 1770, and so was alive in 1766
# T146431
# No dates for Euripides.
# T146432
# No dates for Euripides.
# T146557
# Le Neve, John died in 1741, and so was alive in 1719
# T146558
# Le Neve, John died in 1741, and so was alive in 1718
# T146559
# Le Neve, John died in 1741, and so was alive in 1719
# T146560
# Le Neve, John died in 1741, and so was alive in 1718
# T146561
# Le Neve, John died in 1741, and so was alive in 1717
# T146573
# Laurence, John died in 1732, and so was alive in 1726
# T146616
# Wake, William died in 1737, and so was alive in 1720
# T146620
# Swift, Jonathan died in 1745, and so was alive in 1737
# T146655
# Jortin, John died in 1770, and so was alive in 1755
# T146714
# No dates for Thomas, Pascoe.
# T146724
# Dyche, Thomas died in 1733, and so was already dead by 1735
# T146877
# T146995
# Jortin, John died in 1770, and so was alive in 1758
# T147002
# Le Neve, John died in 1741, and so was alive in 1720
# T147007
# La Vallière, Françoise-Louise de La Baume Le Blanc died in 1710, and so was already dead by 1774
# T147073
# Pegge, Samuel died in 1796, and so was alive in 1765
# T147083
# Jortin, John died in 1770, and so was alive in 1751
# T147089
# T147097
# T147145
# Hasselquist, Fredric died in 1752, and so was already dead by 1766
# T147153
# No dates for Xenophon
# T147190
# Rymer, Thomas died in 1713, and so was already dead by 1726
# T147297
# Brown, John died in 1766, and so was alive in 1757
# T147331
# T147350
# No dates for Isocrates.
# T147422
# No dates for Philo
# T147423
# No dates for Philo
# T147434
# Richardson, John died in 1725, and so was already dead by 1726
# T147441
# T147445
# T147457
# Zinzendorf, Nicolaus Ludwig died in 1760, and so was alive in 1742
# T147470
# T147521
# No dates for Xenophon
# T147615
# Llwyd, Humphrey died in 1568, and so was already dead by 1731
# T147622
# Brown, John died in 1766, and so was alive in 1757
# T147623
# Brown, John died in 1766, and so was alive in 1757
# T147668
# Leslie, Charles died in 1722, and so was alive in 1721
# T147673
# Brown, John died in 1766, and so was alive in 1757
# T147677
# North, Roger died in 1734, and so was already dead by 1740
# T147695
# Milward, Edward died in 1757, and so was alive in 1734
# T147697
# Morant, Philip died in 1770, and so was alive in 1768
# T147706
# Swift, Jonathan died in 1745, and so was alive in 1732
# T147909
# Hoadly, Benjamin died in 1761, and so was already dead by 1773
# T147911
# Brownrigg, William died in 1800, and so was alive in 1748
# T148129
# Plantavit de la Pause, Guillaume died in 1760, and so was alive in 1735
# T148135
# Bowyer, William died in 1777, and so was alive in 1772
# T148161
# Hill, Richard died in 1808, and so was alive in 1770
# T148301
# Brown, John died in 1766, and so was alive in 1763
# T148422
# Parry, Richard died in 1780, and so was alive in 1765
# T148505
# Thompson, George died in 1751, and so was alive in 1732
# T148506
# Rucellai, Bernardo died in 1514, and so was already dead by 1724
# T148509
# No dates for Pennington, W.
# T148510
# Palmer, Samuel died in 1732, and so was already dead by 1733
# T148544
# Douglass, William died in 1752, and so was already dead by 1760
# T148840
# Douglas, John died in 1743, and so was alive in 1727
# T148933
# T148968
# No dates for Cicero, Marcus Tullius.
# T149053
# Burke, Edmund died in 1797, and so was alive in 1769
# T149126
# T43190
# Stanhope, George died in 1728, and so was alive in 1713
# T43223
# Brown, John died in 1766, and so was alive in 1749
# T43291
# Hurd, Richard died in 1808, and so was alive in 1751
# T43293
# Beveridge, William died in 1708, and so was already dead by 1712
# T43311
# Mead, Richard died in 1754, and so was alive in 1724
# T43314
# Lawrence, Thomas died in 1783, and so was alive in 1748
# T43317
# Healde, Thomas died in 1789, and so was alive in 1765
# T43318
# Hale, Richard died in 1728, and so was alive in 1725
# T43436
# Bulstrode, Richard died in 1711, and so was already dead by 1712
# T43452
# Middleton, Conyers died in 1750, and so was already dead by 1776
# T43500
# Shakespeare, William died in 1616, and so was already dead by 1773
# T43656
# Wesley, Samuel died in 1739, and so was alive in 1732
# T43726
# Fawkes, Francis died in 1777, and so was alive in 1767
# T43739
# Pilkington, Matthew died in 1765, and so was alive in 1756
# T43830
# Collins, Arthur died in 1760, and so was alive in 1741
# T43973
# Swift, Jonathan died in 1745, and so was alive in 1738
# T44120
# Barnes, William George died in 1701, and so was already dead by 1738
# T44156
# Nelson, Robert died in the same year the work was published. Need more information.
# T44288
# Bisse, Thomas died in 1731, and so was alive in 1716
# T44314
# Whiston, William died in 1752, and so was alive in 1736
# T44450
# Gastrell, Francis died in 1725, and so was alive in 1722
# T44469
# T44486
# Barrington, Daines died in 1800, and so was alive in 1775
# T44579
# Stanhope, George died in 1728, and so was alive in 1718
# T44645
# Spinckes, Nathaniel died in 1727, and so was alive in 1720
# T44669
# T44681
# T44682
# T44683
# T44684
# T44685
# T44687
# T44705
# T44769
# T44770
# T44796
# T44845
# Reynolds, Richard died in 1744, and so was alive in 1735
# T44949
# No dates for Gratian, Theodorus.
# T45062
# Senhouse, Peter died in 1760, and so was alive in 1728
# T45355
# Cantrell, Henry died in 1773, and so was alive in 1716
# T45393
# No dates for Burroughs, Jeremiah
# T45467
# Campbell, John died in 1775, and so was alive in 1741
# T45538
# T45543
# T45554
# T45563
# T45586
# T45673
# Randolph, Herbert died in 1755, and so was alive in 1729
# T45794
# Berkeley, George died in 1753, and so was alive in 1744
# T45853
# Warburton, William died in 1779, and so was alive in 1745
# T45907
# St. John, Pawlet died in 1732, and so was alive in 1723
# T45908
# St. John, Pawlet died in 1732, and so was alive in 1723
# T45923
# Moss, Robert died in 1729, and so was alive in 1712
# T46009
# No dates for Steele, Joshua.
# T46134
# No dates for Horace.
# T46136
# No dates for Horace.
# T46139
# No dates for Horace.
# T46141
# No dates for Horace.
# T46143
# No dates for Horace.
# T46144
# No dates for Horace.
# T46145
# No dates for Horace.
# T46306
# Bisse, Thomas died in 1731, and so was alive in 1720
# T46375
# T46397
# T46434
# Long, Roger died in 1770, and so was alive in 1736
# T46456
# T46532
# Dennis, John died in 1734, and so was alive in 1711
# T46599
# T46601
# Hildrop, John died in 1756, and so was alive in 1722
# T46627
# Clarke, Joseph died in 1750, and so was alive in 1746
# T46673
# Buckingham, George Villiers died in 1687, and so was already dead by 1734
# T46717
# Synge, Edward died in 1741, and so was alive in 1713
# T46733
# Costa, Uriel died in 1640, and so was already dead by 1740
# T46764
# Towne, John died in 1791, and so was alive in 1766
# T46765
# Towne, John died in 1791, and so was alive in 1766
# T46789
# Brown, John died in 1766, and so was alive in 1764
# T46851
# T46853
# No dates for Hall, Fayrer.
# T46872
# Mangey, Thomas died in 1755, and so was alive in 1718
# T46913
# King, William died in the same year the work was published. Need more information.
# T46960
# Gibbs, James died in 1754, and so was alive in 1732
# T47046
# Cockman, Thomas died in 1745, and so was alive in 1733
# T47115
# Grigg, J. died in 1768, and so was alive in 1745
# T47253
# Bedford, Hilkiah died in 1724, and so was alive in 1710
# T47267
# Berriman, William died in 1750, and so was alive in 1719
# T47291
# Martin, David died in 1721, and so was alive in 1719
# T47329
# Warburton, William died in 1779, and so was alive in 1766
# T47336
# Mackworth, Humphrey died in 1727, and so was alive in 1711
# T47341
# Middleton, Conyers died in 1750, and so was alive in 1719
# T47426
# Bernard, Francis died in 1779, and so was alive in 1774
# T47427
# Bernard, Francis died in 1779, and so was alive in 1774
# T47428
# Bernard, Francis died in 1779, and so was alive in 1774
# T47433
# T47452
# Cooke, William died in 1797, and so was alive in 1750
# T47461
# No dates for English freeholder.
# T47469
# Watson, William died in 1787, and so was alive in 1746
# T47526
# King, William died in 1763, and so was alive in 1739
# T47582
# Owen, Edward died in 1750, and so was alive in 1746
# T47618
# Owen, Edward died in 1750, and so was alive in 1749
# T47632
# Bullock, Richard died in 1809, and so was alive in 1754
# T47674
# Parker, William died in 1802, and so was alive in 1757
# T47680
# Baker, William died in 1733, and so was alive in 1727
# T47699
# Wilcox, John died in 1762, and so was alive in 1738
# T47705
# Whalley, John died in 1748, and so was alive in 1740
# T47706
# Whalley, John died in 1748, and so was alive in 1740
# T47724
# Gilbert, John died in 1761, and so was alive in 1742
# T47731
# Ashburnham, William died in 1797, and so was alive in 1755
# T47785
# Lowth, Robert died in 1787, and so was alive in 1767
# T47801
# Stanhope, George died in 1728, and so was alive in 1710
# T47811
# Bell, George died in 1734, and so was alive in 1713
# T47836
# Abdy, Stotherd died in 1773, and so was alive in 1759
# T47853
# Barton, Philip died in 1796, and so was alive in 1766
# T47938
# Leng, John died in 1727, and so was alive in 1719
# T48069
# Webb, Philip Carteret died in 1770, and so was alive in 1756
# T48107
# Mastini, Antonio died in 1805, and so was alive in 1770
# T48149
# Mead, Richard died in 1754, and so was alive in 1720
# T48168
# No dates for Frere, George.
# T48205
# Mackworth, Humphrey died in 1727, and so was alive in 1710
# T48235
# Holland, Richard died in the same year the work was published. Need more information.
# T48293
# Synge, Edward died in 1741, and so was alive in 1716
# T48320
# Crowne died in 1712, and so was already dead by 1735
# T48383
# Lennox, Charlotte died in 1804, and so was alive in 1769
# T48394
# Smith, George died in 1776, and so was alive in 1770
# T48486
# Bisse, Thomas died in 1731, and so was alive in 1728
# T48492
# Swift, Jonathan died in 1745, and so was alive in 1732
# T48584
# Webb, Philip Carteret died in 1770, and so was alive in 1758
# T48655
# T48758
# T48936
# Edwards, Thomas died in 1757, and so was alive in 1748
# T48975
# Stow, John died in 1605, and so was already dead by 1720
# T49009
# Gally, Henry died in 1769, and so was alive in 1739
# T49034
# Gastrell, Francis died in 1725, and so was alive in 1714
# T49063
# St. John, Pawlet died in 1732, and so was alive in 1712
# T49091
# Snape, Andrew died in 1742, and so was alive in 1710
# T49119
# Lupton, William died in 1726, and so was alive in 1717
# T49120
# Lupton, William died in 1726, and so was alive in 1717
# T49121
# Waterland, Daniel died in 1740, and so was alive in 1722
# T49122
# Sacheverell, Henry died in 1724, and so was alive in 1714
# T49168
# Reeves, William died in 1726, and so was alive in 1714
# T49209
# Fiddes, Richard died in 1725, and so was alive in 1714
# T49239
# Ellis, John died in 1776, and so was alive in 1773
# T49268
# T49322
# Ibbetson, James died in 1781, and so was alive in 1755
# T49354
# T49367
# Masters, Robert died in 1798, and so was alive in 1772
# T49398
# Field, Nathaniel died in 1666, and so was already dead by 1717
# T49408
# Perronet, Vincent died in 1785, and so was alive in 1745
# T49412
# MacAulay, Alexander died in 1766, and so was alive in 1737
# T49659
# Sacheverell, Henry died in 1724, and so was alive in 1710
# T49660
# Sacheverell, Henry died in 1724, and so was alive in 1710
# T49729
# Brydges, Henry died in 1728, and so was alive in 1721
# T49867
# Thomson, James died in 1748, and so was already dead by 1776
# T49910
# Graham, George died in 1767, and so was alive in 1763
# T49963
# Steele, Richard died in 1729, and so was already dead by 1735
# T50005
# Synge, Edward died in 1741, and so was alive in 1712
# T50203
# Burke, Edmund died in 1797, and so was alive in 1770
# T50204
# Burke, Edmund died in 1797, and so was alive in 1770
# T50205
# Burke, Edmund died in 1797, and so was alive in 1770
# T50206
# Burke, Edmund died in 1797, and so was alive in 1770
# T50305
# Whiston, William died in 1752, and so was alive in 1742
# T50400
# Jacob, Hildebrand died in 1739, and so was alive in 1737
# T50497
# Keeling, Bartholomew died in 1778, and so was alive in 1755
# T50669
# T50695
# Nugent, Robert Nugent died in 1788, and so was alive in 1775
# T50780
# Hazeland, William died in 1763, and so was alive in 1756
# T50805
# No dates for Castell, Robert.
# T50820
# Swift, Jonathan died in 1745, and so was alive in 1730
# T50839
# Warburton, William died in 1779, and so was alive in 1738
# T50846
# Sherlock, Thomas died in 1761, and so was alive in 1718
# T50848
# Sherlock, Thomas died in 1761, and so was alive in 1718
# T50861
# Bedford, Hilkiah died in 1724, and so was alive in 1717
# T50863
# T50866
# Le Moine, Abraham died in 1757, and so was alive in 1751
# T50892
# King, William died in 1712, and so was alive in 1711
# T50893
# King, William died in 1712, and so was alive in 1711
# T50914
# Drake, Samuel died in 1753, and so was alive in 1719
# T51233
# Whiston, William died in 1752, and so was alive in 1737
# T51238
# No dates for Bambridge, Thomas
# T51363
# No dates for Castleton, Nathaniel.
# T51364
# Trapp, Joseph died in 1747, and so was alive in 1711
# T51503
# Bellinger, Francis died in 1721, and so was alive in 1717
# T51520
# No dates for Walker, Samuel
# T51603
# T51618
# T51619
# T51649
# Jackson, John died in 1763, and so was alive in 1748
# T51786
# Middleton, Conyers died in 1750, and so was alive in 1720
# T51797
# T51798
# T51799
# No dates for Bond, Denis
# T51800
# No dates for Bond, Denis
# T51804
# T51805
# Grant, Archibald died in 1778, and so was alive in 1732
# T51807
# T51834
# T51846
# T52058
# Tucker, Josiah died in 1799, and so was alive in 1749
# T52062
# T52091
# T52180
# No dates for Baynes, Walter.
# T52272
# Synge, Edward died in 1741, and so was alive in 1734
# T52312
# Fielding, Henry died in 1754, and so was alive in 1743
# T52518
# Beaumont, John died in 1731, and so was alive in 1714
# T52529
# No dates for Nisbet, Janet.
# T52750
# Swift, Jonathan died in 1745, and so was already dead by 1766
# T52751
# Swift, Jonathan died in 1745, and so was already dead by 1766
# T52752
# Swift, Jonathan died in 1745, and so was already dead by 1768
# T52754
# Swift, Jonathan died in 1745, and so was already dead by 1775
# T52755
# Swift, Jonathan died in 1745, and so was already dead by 1755
# T52757
# Swift, Jonathan died in 1745, and so was already dead by 1775
# T52800
# Farquhar, George died in 1707, and so was already dead by 1711
# T52801
# Farquhar, George died in 1707, and so was already dead by 1718
# T230782
# Moore, Francis died in 1714, and so was already dead by 1775
# T231218
# No dates for Spencer, Richard
# T231296
# T144689
# Burnet, Gilbert died in 1715, and so was already dead by 1724
# T232322
# Nichols, John died in 1826, and so was alive in 1763
# T483136
# T483329
# No dates for Ward, Caesar.
# N471245
# N471393
# N472379
# Centlivre, Susanna died in 1723, and so was already dead by 1734
# N472853
# Jortin, John died in 1770, and so was already dead by 1774
# N472860
# N473545
# N474015
# No dates for Loughton, William.
# N474210
# Folkes, Martin died in 1754, and so was already dead by 1763
# N474724
# Shakespeare, William died in 1616, and so was already dead by 1774
# N475027
# Arnall, William died in 1700, and so was already dead by 1730
# N475493
# N478215
# T478506
# T479232
# Allen, John died in 1741, and so was alive in 1729
# N479419
# Gibbs, James died in 1754, and so was alive in 1736
# N479472
# N490104
# Palairet, Elias died in 1765, and so was alive in 1757
# T490494
# Bridges, John died in 1724, and so was already dead by 1739

# %% [markdown]
# ## Construct a data structure to hold on to all this information
# In Python, as in other languages, there are different kinds of data structures that have different properties that make them well-suited to different uses. So far, we've only dealt with lists. Let's explore a somewhat more involved data type for holding all the information we're getting about living vs. dead authors.
#
# A dictionary stores information in key/value pairs. That is, for each value there's a corresponding label. Dictionaries can hold any kind of data, including not just strings or integers, but also lists or other dictionaries (as well as another data type—the tuple—that we may run into later). So dictionaries can end up being complex, nested data structures, if need be.
#
# For our purposes, let's keep track of living vs. dead authors for each year. One way to organize our data might be:
#
# ```
# {
#   1710:
#         {'total_works': <integer-value>,
#          'no_author': <integer_value>,
#          'living_authors': <integer-value>,
#          'dead_authors': <integer-value>,
#          'ambiguous': <integer_value>
#         },
#   1711:
#         {'total_works': <integer-value>,
#          'no_author': <integer_value>,
#          'living_authors': <integer-value>,
#          'dead_authors': <integer-value>,
#          'ambiguous': <integer_value>
#         },
# ...
#   1778:
#         {'total_works': <integer-value>,
#          'no_author': <integer_value>,
#          'living_authors': <integer-value>,
#          'dead_authors': <integer-value>,
#          'ambiguous': <integer_value>
#         }
# }
# ```

# %% [markdown]
# We'll need to iterate through our list of MARC records and update the number in each category for each year as we go. The way we work with dictionaries is a bit like how we work with lists, but instead of always having numeric indices, dictionaries have "keys" that can be strings, integers, or tuples. (For now, suffice it to say that tuples are [kind of like lists, but different](https://diveintopython3.net/native-datatypes.html#tuples).)
#
# So to get the values for a given year, we would give the dictionary name followed by the key in square brackets (e.g. `author_count[1730]`). Because the value for each year is *another* dictionary, we would get those values by providing the key for the nested dictionary (e.g., `author_count[1730]['total_works']`—note that, while `1730` is an integer, `'total_works'` is a string, so `'total_works'` needs to be in quotation marks, while `1730` doesn't).
#
# For each record we encounter, the first thing we'll get is the publication year. If it's the first record we've seen for that year, we'll create a new entry in the dictionary using `setdefault()`: this creates a new key/value pair with default values. Our default value will be a dictionary with all of the nested values set to 0.
#
# If there's already key for our `pub_year` in the dictionary (or if we've just created a new one), we'll figure out which value in the nested dictionary we need to increase and then add one to that value.

# %%
#Code cell #26
#Create an empty dictionary to hold our information
author_count = {}

with open(directory_path + '2023_d1_estc_bowyer_full.mrc', 'rb') as marc_file :
  marc_reader = MARCReader(marc_file)
  for record in marc_reader :
    #Get a substring from MARC field 008 and convert it to an integer
    pub_year = int(record['008'].data[7:11])

    #If we don't already have an entry in the author_count dictionary for this
    #year, create one, with the year as a key. Give that key a value of a
    #dictionary starting with empty counts for all the categories
    author_count.setdefault(pub_year, {'total_works': 0,
                                       'no_author': 0,
                                       'living_authors': 0,
                                       'dead_authors': 0,
                                       'ambiguous': 0
                                       })
    #Immediately increase the number of total works—we don't know anything else
    #yet, but we do know that much.
    author_count[pub_year]['total_works'] += 1

    if record.get('100', None) is not None :
      author_name = record['100']['a'].rstrip(',')
      #Just in case some records don't have a date for the author, at all,
      #as can happen with ancient authors as well as pseudonymous ones.
      if record.get('100', None).get('d', None) is not None :
        date_string = record['100']['d']

        #Pass the death year (still a string) to the get_death_year function
        death_year = get_death_year(date_string)

        #If we get back a result from get_death_year other than 'None'...
        if death_year is not None :

          #Turn that result into an integer
          death_year = int(death_year)

          #Compare the death year to the publication year, and increment
          #values in our dictionary accordingly
          if death_year > pub_year :
            author_count[pub_year]['living_authors'] += 1
          elif death_year == pub_year :
            author_count[pub_year]['ambiguous'] += 1
          else :
            author_count[pub_year]['dead_authors'] += 1

      #If there are no dates
      else :
        author_count[pub_year]['ambiguous'] += 1
    #If there's no author at all
    else :
      author_count[pub_year]['no_author'] += 1

# %%
#Code cell #27
for k, v in author_count.items() :
  print(k)
  print(v)
# Out:
# 1758
# {'total_works': 46, 'no_author': 9, 'living_authors': 18, 'dead_authors': 8, 'ambiguous': 8}
# 1728
# {'total_works': 50, 'no_author': 12, 'living_authors': 22, 'dead_authors': 6, 'ambiguous': 9}
# 1733
# {'total_works': 66, 'no_author': 17, 'living_authors': 24, 'dead_authors': 15, 'ambiguous': 6}
# 1767
# {'total_works': 43, 'no_author': 4, 'living_authors': 25, 'dead_authors': 9, 'ambiguous': 5}
# 1710
# {'total_works': 45, 'no_author': 12, 'living_authors': 27, 'dead_authors': 3, 'ambiguous': 2}
# 1768
# {'total_works': 37, 'no_author': 10, 'living_authors': 14, 'dead_authors': 10, 'ambiguous': 3}
# 1720
# {'total_works': 104, 'no_author': 14, 'living_authors': 60, 'dead_authors': 11, 'ambiguous': 18}
# 1743
# {'total_works': 31, 'no_author': 9, 'living_authors': 16, 'dead_authors': 1, 'ambiguous': 4}
# 1761
# {'total_works': 51, 'no_author': 13, 'living_authors': 20, 'dead_authors': 15, 'ambiguous': 3}
# 1774
# {'total_works': 47, 'no_author': 6, 'living_authors': 22, 'dead_authors': 14, 'ambiguous': 4}
# 1749
# {'total_works': 54, 'no_author': 14, 'living_authors': 15, 'dead_authors': 14, 'ambiguous': 9}
# 1751
# {'total_works': 54, 'no_author': 9, 'living_authors': 29, 'dead_authors': 12, 'ambiguous': 2}
# 1736
# {'total_works': 32, 'no_author': 6, 'living_authors': 19, 'dead_authors': 4, 'ambiguous': 2}
# 1750
# {'total_works': 48, 'no_author': 7, 'living_authors': 23, 'dead_authors': 9, 'ambiguous': 8}
# 1760
# {'total_works': 32, 'no_author': 7, 'living_authors': 17, 'dead_authors': 4, 'ambiguous': 3}
# 1770
# {'total_works': 48, 'no_author': 12, 'living_authors': 22, 'dead_authors': 6, 'ambiguous': 4}
# 1759
# {'total_works': 36, 'no_author': 7, 'living_authors': 9, 'dead_authors': 13, 'ambiguous': 5}
# 1719
# {'total_works': 96, 'no_author': 12, 'living_authors': 63, 'dead_authors': 8, 'ambiguous': 10}
# 1765
# {'total_works': 50, 'no_author': 9, 'living_authors': 19, 'dead_authors': 19, 'ambiguous': 3}
# 1772
# {'total_works': 53, 'no_author': 8, 'living_authors': 24, 'dead_authors': 13, 'ambiguous': 3}
# 1727
# {'total_works': 48, 'no_author': 8, 'living_authors': 20, 'dead_authors': 12, 'ambiguous': 5}
# 1766
# {'total_works': 64, 'no_author': 12, 'living_authors': 31, 'dead_authors': 16, 'ambiguous': 4}
# 1744
# {'total_works': 51, 'no_author': 8, 'living_authors': 21, 'dead_authors': 11, 'ambiguous': 6}
# 1722
# {'total_works': 66, 'no_author': 14, 'living_authors': 28, 'dead_authors': 8, 'ambiguous': 13}
# 1742
# {'total_works': 55, 'no_author': 14, 'living_authors': 22, 'dead_authors': 13, 'ambiguous': 5}
# 1745
# {'total_works': 52, 'no_author': 7, 'living_authors': 25, 'dead_authors': 7, 'ambiguous': 11}
# 1740
# {'total_works': 49, 'no_author': 7, 'living_authors': 24, 'dead_authors': 6, 'ambiguous': 10}
# 1726
# {'total_works': 73, 'no_author': 12, 'living_authors': 33, 'dead_authors': 9, 'ambiguous': 13}
# 1748
# {'total_works': 66, 'no_author': 9, 'living_authors': 33, 'dead_authors': 17, 'ambiguous': 6}
# 1763
# {'total_works': 52, 'no_author': 7, 'living_authors': 26, 'dead_authors': 12, 'ambiguous': 6}
# 1769
# {'total_works': 53, 'no_author': 8, 'living_authors': 31, 'dead_authors': 9, 'ambiguous': 1}
# 1754
# {'total_works': 42, 'no_author': 11, 'living_authors': 20, 'dead_authors': 10, 'ambiguous': 1}
# 1771
# {'total_works': 41, 'no_author': 6, 'living_authors': 21, 'dead_authors': 4, 'ambiguous': 5}
# 1711
# {'total_works': 54, 'no_author': 10, 'living_authors': 27, 'dead_authors': 8, 'ambiguous': 7}
# 1735
# {'total_works': 68, 'no_author': 8, 'living_authors': 27, 'dead_authors': 17, 'ambiguous': 14}
# 1737
# {'total_works': 64, 'no_author': 9, 'living_authors': 34, 'dead_authors': 11, 'ambiguous': 8}
# 1716
# {'total_works': 50, 'no_author': 12, 'living_authors': 19, 'dead_authors': 10, 'ambiguous': 6}
# 1746
# {'total_works': 56, 'no_author': 7, 'living_authors': 26, 'dead_authors': 17, 'ambiguous': 4}
# 1739
# {'total_works': 83, 'no_author': 17, 'living_authors': 41, 'dead_authors': 8, 'ambiguous': 16}
# 1714
# {'total_works': 56, 'no_author': 11, 'living_authors': 31, 'dead_authors': 9, 'ambiguous': 2}
# 1729
# {'total_works': 62, 'no_author': 13, 'living_authors': 19, 'dead_authors': 14, 'ambiguous': 11}
# 1773
# {'total_works': 54, 'no_author': 7, 'living_authors': 30, 'dead_authors': 11, 'ambiguous': 5}
# 1732
# {'total_works': 114, 'no_author': 30, 'living_authors': 47, 'dead_authors': 12, 'ambiguous': 15}
# 1723
# {'total_works': 59, 'no_author': 8, 'living_authors': 24, 'dead_authors': 18, 'ambiguous': 6}
# 1730
# {'total_works': 104, 'no_author': 20, 'living_authors': 43, 'dead_authors': 24, 'ambiguous': 14}
# 1757
# {'total_works': 52, 'no_author': 6, 'living_authors': 27, 'dead_authors': 18, 'ambiguous': 0}
# 1717
# {'total_works': 65, 'no_author': 8, 'living_authors': 37, 'dead_authors': 11, 'ambiguous': 7}
# 1734
# {'total_works': 67, 'no_author': 15, 'living_authors': 23, 'dead_authors': 21, 'ambiguous': 6}
# 1764
# {'total_works': 57, 'no_author': 11, 'living_authors': 31, 'dead_authors': 10, 'ambiguous': 4}
# 1752
# {'total_works': 54, 'no_author': 9, 'living_authors': 27, 'dead_authors': 15, 'ambiguous': 2}
# 1712
# {'total_works': 39, 'no_author': 1, 'living_authors': 26, 'dead_authors': 7, 'ambiguous': 2}
# 1725
# {'total_works': 56, 'no_author': 9, 'living_authors': 19, 'dead_authors': 8, 'ambiguous': 19}
# 1762
# {'total_works': 24, 'no_author': 3, 'living_authors': 10, 'dead_authors': 9, 'ambiguous': 1}
# 1715
# {'total_works': 48, 'no_author': 8, 'living_authors': 18, 'dead_authors': 4, 'ambiguous': 14}
# 1731
# {'total_works': 74, 'no_author': 22, 'living_authors': 26, 'dead_authors': 12, 'ambiguous': 10}
# 1755
# {'total_works': 64, 'no_author': 6, 'living_authors': 38, 'dead_authors': 9, 'ambiguous': 9}
# 1753
# {'total_works': 43, 'no_author': 11, 'living_authors': 19, 'dead_authors': 9, 'ambiguous': 4}
# 1713
# {'total_works': 33, 'no_author': 3, 'living_authors': 18, 'dead_authors': 5, 'ambiguous': 5}
# 1721
# {'total_works': 82, 'no_author': 16, 'living_authors': 41, 'dead_authors': 15, 'ambiguous': 8}
# 1775
# {'total_works': 41, 'no_author': 4, 'living_authors': 17, 'dead_authors': 14, 'ambiguous': 4}
# 1747
# {'total_works': 37, 'no_author': 8, 'living_authors': 15, 'dead_authors': 9, 'ambiguous': 1}
# 1741
# {'total_works': 55, 'no_author': 13, 'living_authors': 22, 'dead_authors': 12, 'ambiguous': 6}
# 1718
# {'total_works': 56, 'no_author': 5, 'living_authors': 30, 'dead_authors': 16, 'ambiguous': 3}
# 1776
# {'total_works': 35, 'no_author': 5, 'living_authors': 16, 'dead_authors': 11, 'ambiguous': 3}
# 1724
# {'total_works': 53, 'no_author': 8, 'living_authors': 16, 'dead_authors': 14, 'ambiguous': 7}
# 1756
# {'total_works': 43, 'no_author': 6, 'living_authors': 25, 'dead_authors': 8, 'ambiguous': 2}
# 1777
# {'total_works': 38, 'no_author': 8, 'living_authors': 17, 'dead_authors': 10, 'ambiguous': 2}
# 1738
# {'total_works': 70, 'no_author': 5, 'living_authors': 46, 'dead_authors': 12, 'ambiguous': 6}
# 1778
# {'total_works': 8, 'no_author': 3, 'living_authors': 2, 'dead_authors': 2, 'ambiguous': 1}
# 1780
# {'total_works': 4, 'no_author': 1, 'living_authors': 3, 'dead_authors': 0, 'ambiguous': 0}
# 1779
# {'total_works': 3, 'no_author': 1, 'living_authors': 0, 'dead_authors': 1, 'ambiguous': 1}

# %% [markdown]
# ## Do something with these data
# Now we have all our data in a dictionary, we'll want to do something with them so we can get a sense of the answer to our question. First we'll save the data to a spreadsheet, then we'll construct a (rudimentary) bar chart.

# %% [markdown]
# ### Saving to a file
# We'll use the `pandas` library to convert the data in our dictionary to a DataFrame and save it as an Excel spreadsheet.

# %%
#Code cell #28
#Import pandas and os library—in case we're trying to write a file to
#a folder that doesn't exist yet
import pandas as pd
import os

#Set a variable containing the path to the output directory. See if this
#directory exists and, if it doesn't create it
output_directory = '/gdrive/MyDrive/rbs_digital_approaches_2023/output/'
if os.path.exists(output_directory) is not True :
  os.makedirs(output_directory)

df = pd.DataFrame.from_dict(author_count, orient='index')
df.sort_index(inplace=True)
df
df.to_excel(output_directory + 'living_vs_dead_authors.xlsx')

# %% [markdown]
# ## Making a bar chart with plotly
# It seems like we ought to at least have something to look at at the end of all this. Let's use the `plotly` package to draw a bar chart comparing the number of living and dead authors in each year .

# %%
#Code cell #29
#Import the module we need from the plotly package. (Plotly is installed by
#default in Google Colaboratory. In another environment, you might need to
#install it using pip)
import plotly.graph_objects as go

#Create empty lists for the years that we'll use as our x axis and for the counts
#that we'll chart on our y axis
years = []
living_counts = []
dead_counts = []

#Iterate through the keys and add values to our lists
for year, values in author_count.items() :
  years.append(year)
  living_counts.append(values['living_authors'])
  dead_counts.append(values['dead_authors'])

#There's a more compact syntax for creating those lists, but one that might be
#a little opaque if you're new to Python:
#years = [k for k, v in author_counts.items()]
#living_counts = [v['living_authors'] for k, v in author_counts.items()]
#dead_counts = [v['dead_authors'] for k, v in author_counts.items()]

#Create the chart using the plotly graph objects module. The "data" is a list of
#two graph_objects "bars," each of which has a label ("name"), and each of which
#takes its values for the x and y axes from the lists we constructed above.
fig = go.Figure(data=[
    go.Bar(name='Living', x=years, y=living_counts),
    go.Bar(name='Dead', x=years, y=dead_counts)
])

# Change the bar mode to group the bars together
fig.update_layout(barmode='group')

#Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="41a452d7-1c65-4822-8d69-0fda702c9719" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41a452d7-1c65-4822-8d69-0fda702c9719")) {                    Plotly.newPlot(                        "41a452d7-1c65-4822-8d69-0fda702c9719",                        [{"name":"Living","x":[1758,1728,1733,1767,1710,1768,1720,1743,1761,1774,1749,1751,1736,1750,1760,1770,1759,1719,1765,1772,1727,1766,1744,1722,1742,1745,1740,1726,1748,1763,1769,1754,1771,1711,1735,1737,1716,1746,1739,1714,1729,1773,1732,1723,1730,1757,1717,1734,1764,1752,1712,1725,1762,1715,1731,1755,1753,1713,1721,1775,1747,1741,1718,1776,1724,1756,1777,1738,1778,1780,1779],"y":[18,22,24,25,27,14,60,16,20,22,15,29,19,23,17,22,9,63,19,24,20,31,21,28,22,25,24,33,33,26,31,20,21,27,27,34,19,26,41,31,19,30,47,24,43,27,37,23,31,27,26,19,10,18,26,38,19,18,41,17,15,22,30,16,16,25,17,46,2,3,0],"type":"bar"},{"name":"Dead","x":[1758,1728,1733,1767,1710,1768,1720,1743,1761,1774,1749,1751,1736,1750,1760,1770,1759,1719,1765,1772,1727,1766,1744,1722,1742,1745,1740,1726,1748,1763,1769,1754,1771,1711,1735,1737,1716,1746,1739,1714,1729,1773,1732,1723,1730,1757,1717,1734,1764,1752,1712,1725,1762,1715,1731,1755,1753,1713,1721,1775,1747,1741,1718,1776,1724,1756,1777,1738,1778,1780,1779],"y":[8,6,15,9,3,10,11,1,15,14,14,12,4,9,4,6,13,8,19,13,12,16,11,8,13,7,6,9,17,12,9,10,4,8,17,11,10,17,8,9,14,11,12,18,24,18,11,21,10,15,7,8,9,4,12,9,9,5,15,14,9,12,16,11,14,8,10,12,2,0,1],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e ...

# %% [markdown]
# ## And there we have it
# This notebook has walked through a practical approach to a concrete question that we might want to ask about the books described in a set of MARC records. There are plenty of nuances we'd want to add to our approach to these data if we were really approaching this as a research question, but even this fairly simple example manages to touch on many of the fundamental coding tasks that you will run into again and again in this kind of work.
#
# * We opened, read, and wrote files,
# * We reused code—both by importing several different Python packages for different specialized tasks and by writing a function to make some of our own code more easily reusable.
# * We worked in several different ways with different data types and structures (strings, integers, lists, and dictionaries).
# * We iterated through various pieces of information, examining each in turn.
# * We added conditions and control structures to deal with branching sets of options as we iterated through our information.
#
# Learning to break questions down into these kinds of smaller steps that are suited to what computers do well is at the heart of digital work. Not all coding questions are simple, certainly, and neither is all code. But there's a lot of complexity that emerges from what are, at bottom, fairly simple operations.
